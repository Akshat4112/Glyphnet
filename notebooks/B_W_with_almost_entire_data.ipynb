# %% [markdown]
# ## Data Preprocessing

# %%
# Import Libraries
 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image, ImageDraw, ImageFont, ImageEnhance
import urllib.request
import pickle

# %%
data = pickle.load(urllib.request.urlopen('https://github.com/endgameinc/homoglyph/blob/master/data/domains_spoof.pkl?raw=true'))

# %%
data
# Out:
# {'test': [('meiwajisyo.com', 'mekwajisyo.com', 1.0),
#   ('meiwajisyo.com', 'meiawijsyo.com', 1.0),
#   ('meiwajisyo.com', 'meiwa-ijsoy.com', 1.0),
#   ('meiwajisyo.com', 'męiwajisyo.com', 1.0),
#   ('meiwajisyo.com', 'meįwąjisyo.com', 1.0),
#   ('meiwajisyo.com', 'meiwàjišÿo.com', 1.0),
#   ('meiwajisyo.com', 'meiwajiryò.com', 1.0),
#   ('meiwajisyo.com', 'leiwâjiŝyo.com', 1.0),
#   ('meiwajisyo.com', 'rneiwaijsyô.com', 1.0),
#   ('webfactorydesign.com', 'wdbfactorydesign.com', 1.0),
#   ('webfactorydesign.com', 'webfacttorydesgin.com', 1.0),
#   ('webfactorydesign.com', 'webfictorydesgkn.com', 1.0),
#   ('webfactorydesign.com', 'webfactòrydesign.com', 1.0),
#   ('webfactorydesign.com', 'webfácťorydesign.com', 1.0),
#   ('webfactorydesign.com', 'webſactorŷdesigń.com', 1.0),
#   ('webfactorydesign.com', 'webfactorydesigňe.com', 1.0),
#   ('webfactorydesign.com', 'weƀfacto_rydesigņ.com', 1.0),
#   ('webfactorydesign.com', 'vvebfãctorydesgin.com', 1.0),
#   ('125wyt.com', '125_wyt.com', 1.0),
#   ('125wyt.com', '125wytzt.com', 1.0),
#   ('125wyt.com', '152wytj.com', 1.0),
#   ('125wyt.com', '125wyt.com', 1.0),
#   ('125wyt.com', '125wÿt.com', 1.0),
#   ('125wyt.com', '125wẏŧ.com', 1.0),
#   ('125wyt.com', 'i25wyt.com', 1.0),
#   ('125wyt.com', '124ẅyț.com', 1.0),
#   ('125wyt.com', '12-5Ŵytz.com', 1.0),
#   ('aeonbank.com', 'aeonbaank.com', 1.0),
#   ('aeonbank.com', 'aenbank.com', 1.0),
#   ('aeonbank.com', 'aaenobaok.com', 1.0),
#   ('aeonbank.com', 'aeonbaŉk.com', 1.0),
#   ('aeonbank.com', 'ąeonƀank.com', 1.0),
#   ('aeonbank.com', 'ăeònbanķ.com', 1.0),
#   ('aeonbank.com', 'aeoonƀank.com', 1.0),
#   ('aeonbank.com', 'aeoonƀänk.com', 1.0),
#   ('aeonbank.com', 'aelöbank.com', 1.0),
#   ('filmesonlineagora.com', 'filmesonlineaagora.com', 1.0),
#   ('filmesonlineagora.com', 'filnnesonlineagnra.com', 1.0),
#   ('filmesonlineagora.com', 'b-ilnnesonlineagora.com', 1.0),
#   ('filmesonlineagora.com', 'filmesonlineågora.com', 1.0),
#   ('filmesonlineagora.com', 'filmesonliŉěagora.com', 1.0),
#   ('filmesonlineagora.com', 'filmēsonlīněagora.com', 1.0),
#   ('filmesonlineagora.com', 'filmesońlineag-ora.com', 1.0),
#   ('filmesonlineagora.com', 'filmesónlineago_rą.com', 1.0),
#   ('filmesonlineagora.com', 'fllnneŝonlineagora.com', 1.0),
#   ('edelivery-view.com', 'ede-livery-view.com', 1.0),
#   ('edelivery-view.com', 'edeli_very-iew.com', 1.0),
#   ('edelivery-view.com', 'eeli_veri-view.com', 1.0),
#   ('edelivery-view.com', 'edēlivery-view.com', 1.0),
#   ('edelivery-view.com', 'ėdelivery-view.com', 1.0),
#   ('edelivery-view.com', 'edĕlivery-viĕw.com', 1.0),
#   ('edelivery-view.com', 'edeliveřȑy-v-iew.com', 1.0),
#   ('edelivery-view.com', 'edâlîvery-view.com', 1.0),
#   ('edelivery-view.com', 'edeļi_ver_y-view.com', 1.0),
#   ('pinsalo.com', 'pimsalo.com', 1.0),
#   ('pinsalo.com', 'pnsalos.com', 1.0),
#   ('pinsalo.com', 'pnsanno.com', 1.0),
#   ('pinsalo.com', 'piņsalo.com', 1.0),
#   ('pinsalo.com', 'pinșaĺo.com', 1.0),
#   ('pinsalo.com', 'þinšaļo.com', 1.0),
#   ('pinsalo.com', 'piŉ_salo.com', 1.0),
#   ('pinsalo.com', 'pîŋsal0.com', 1.0),
#   ('pinsalo.com', 'þnsqlo.com', 1.0),
#   ('qq437.com', 'qq437v.com', 1.0),
#   ('qq437.com', 'qq437g.com', 1.0),
#   ('qq437.com', 'q-q4376.com', 1.0),
#   ('qq437.com', 'qq437.com', 1.0),
#   ('qq437.com', 'qq437.com', 1.0),
#   ('qq437.com', 'ԛɋ437.com', 1.0),
#   ('qq437.com', '1q437.com', 1.0),
#   ('qq437.com', 'qq437.com', 1.0),
#   ('qq437.com', 'ԛg437g.com', 1.0),
#   ('checkraka.com', 'checkrake.com', 1.0),
#   ('checkraka.com', 'checkraka6.com', 1.0),
#   ('checkraka.com', 'kheckrakb.com', 1.0),
#   ('checkraka.com', 'checkraķa.com', 1.0),
#   ('checkraka.com', 'cĥeckrakă.com', 1.0),
#   ('checkraka.com', 'chećķrakà.com', 1.0),
#   ('checkraka.com', 'checķrakaa.com', 1.0),
#   ('checkraka.com', 'cchēckřȑaka.com', 1.0),
#   ('checkraka.com', 'cheĉkarkab.com', 1.0),
#   ('hnyxsx.com', 'hnyxsxb.com', 1.0),
#   ('hnyxsx.com', 'hmyhsx.com', 1.0),
#   ('hnyxsx.com', 'hhoyxsx.com', 1.0),
#   ('hnyxsx.com', 'hnyẋsx.com', 1.0),
#   ('hnyxsx.com', 'hnýxʂx.com', 1.0),
#   ('hnyxsx.com', 'hŋýxŝx.com', 1.0),
#   ('hnyxsx.com', 'ĥnyxsxk.com', 1.0),
#   ('hnyxsx.com', '_hñyxʂx.com', 1.0),
#   ('hnyxsx.com', 'hmẏxsxj.com', 1.0),
#   ('xvide0s.com', 'vxide0s.com', 1.0),
#   ('xvide0s.com', 'yvidee0s.com', 1.0),
#   ('xvide0s.com', 'y-vide0s_.com', 1.0),
#   ('xvide0s.com', 'xvide0ș.com', 1.0),
#   ('xvide0s.com', 'ẍvide0s.com', 1.0),
#   ('xvide0s.com', 'ẋviƌe0ś.com', 1.0),
#   ('xvide0s.com', 'xṿie0s.com', 1.0),
#   ('xvide0s.com', 'ẋvide03.com', 1.0),
#   ('xvide0s.com', 'yiđe0s.com', 1.0),
#   ('muviza.com', 'muvkza.com', 1.0),
#   ('muviza.com', 'm_uvizav.com', 1.0),
#   ('muviza.com', 'muvyzavw.com', 1.0),
#   ('muviza.com', 'muvizā.com', 1.0),
#   ('muviza.com', 'muvıẓa.com', 1.0),
#   ('muviza.com', 'ɱūṽiza.com', 1.0),
#   ('muviza.com', 'mųvi2a.com', 1.0),
#   ('muviza.com', 'muvi-ža.com', 1.0),
#   ('muviza.com', 'müvizavf.com', 1.0),
#   ('gns3.com', 'gsn3.com', 1.0),
#   ('gns3.com', 'gns3-.com', 1.0),
#   ('gns3.com', 'gsn3mp.com', 1.0),
#   ('gns3.com', 'gnš3.com', 1.0),
#   ('gns3.com', 'gňs3.com', 1.0),
#   ('gns3.com', 'gñş3.com', 1.0),
#   ('gns3.com', 'gns3č.com', 1.0),
#   ('gns3.com', 'èns3.com', 1.0),
#   ('gns3.com', 'gńs3_m.com', 1.0),
#   ('rockwellcollins.com', 'rockwgllcollins.com', 1.0),
#   ('rockwellcollins.com', 'roc_kwellco_llins.com', 1.0),
#   ('rockwellcollins.com', 'roc_kwellollyns.com', 1.0),
#   ('rockwellcollins.com', 'rockwellcollinʂ.com', 1.0),
#   ('rockwellcollins.com', 'ɍockẃellcollins.com', 1.0),
#   ('rockwellcollins.com', 'rockweľlcolłinŝ.com', 1.0),
#   ('rockwellcollins.com', 'róckwellcollinsx.com', 1.0),
#   ('rockwellcollins.com', 'r-ockwellcoĺlins.com', 1.0),
#   ('rockwellcollins.com', 'roc_kwellcolliŋq.com', 1.0),
#   ('souguge.com', 'sougugea.com', 1.0),
#   ('souguge.com', 'cougugei.com', 1.0),
#   ('souguge.com', 'cuguge.com', 1.0),
#   ('souguge.com', 'šouguge.com', 1.0),
#   ('souguge.com', 'šoúguge.com', 1.0),
#   ('souguge.com', 'ŝouĝugê.com', 1.0),
#   ('souguge.com', 'șuoguge.com', 1.0),
#   ('souguge.com', 'sou6ūğe.com', 1.0),
#   ('souguge.com', 'cougu-ğe.com', 1.0),
#   ('dokkanafkar.com', 'dokknafkar.com', 1.0),
#   ('dokkanafkar.com', 'dokk4nafkarm.com', 1.0),
#   ('dokkanafkar.com', 'doklk4nafkarj.com', 1.0),
#   ('dokkanafkar.com', 'dokkanafķar.com', 1.0),
#   ('dokkanafkar.com', 'doķkānafkar.com', 1.0),
#   ('dokkanafkar.com', 'Ƌökkanaſkar.com', 1.0),
#   ('dokkanafkar.com', 'dok_kanafkar.com', 1.0),
#   ('dokkanafkar.com', 'dokkanafķĭr.com', 1.0),
#   ('dokkanafkar.com', 'dokk4nafķarx.com', 1.0),
#   ('helipal.com', 'henipal.com', 1.0),
#   ('helipal.com', 'helial.com', 1.0),
#   ('helipal.com', 'helihalg.com', 1.0),
#   ('helipal.com', 'ĥelipal.com', 1.0),
#   ('helipal.com', 'heĺipaľ.com', 1.0),
#   ('helipal.com', 'hêlipăľ.com', 1.0),
#   ('helipal.com', 'heliƥaln.com', 1.0),
#   ('helipal.com', 'hĥeĺipal.com', 1.0),
#   ('helipal.com', 'heĺixaln.com', 1.0),
#   ('sportmedia.com', 'wportmedia.com', 1.0),
#   ('sportmedia.com', 'spo6tmedia.com', 1.0),
#   ('sportmedia.com', 'spo6tmedai.com', 1.0),
#   ('sportmedia.com', 'sportmeƌia.com', 1.0),
#   ('sportmedia.com', 'sþortmeďia.com', 1.0),
#   ('sportmedia.com', 'ʂpoŕtɱedia.com', 1.0),
#   ('sportmedia.com', 'sportmeđiaw.com', 1.0),
#   ('sportmedia.com', '_sporŧmediā.com', 1.0),
#   ('sportmedia.com', 'spo2tɱedial.com', 1.0),
#   ('dedoimedo.com', 'dedoimedlo.com', 1.0),
#   ('dedoimedo.com', 'dedoymdo.com', 1.0),
#   ('dedoimedo.com', 'dedoimtop.com', 1.0),
#   ('dedoimedo.com', 'dēdoimedo.com', 1.0),
#   ('dedoimedo.com', 'dedoimeďô.com', 1.0),
#   ('dedoimedo.com', 'ďeƋoímedo.com', 1.0),
#   ('dedoimedo.com', 'dedoì-edo.com', 1.0),
#   ('dedoimedo.com', 'deďoımado.com', 1.0),
#   ('dedoimedo.com', 'decloimƌo.com', 1.0),
#   ('mer30.com', '-er30.com', 1.0),
#   ('mer30.com', 'mm30.com', 1.0),
#   ('mer30.com', '44mp30.com', 1.0),
#   ('mer30.com', 'ɱer30.com', 1.0),
#   ('mer30.com', 'meřȑ30.com', 1.0),
#   ('mer30.com', 'ɱer30.com', 1.0),
#   ('mer30.com', 'mer30ż.com', 1.0),
#   ('mer30.com', 'mĕ30.com', 1.0),
#   ('mer30.com', 'mmr30ĵ.com', 1.0),
#   ('dansdeals.com', 'daansdeals.com', 1.0),
#   ('dansdeals.com', 'dansdeal3.com', 1.0),
#   ('dansdeals.com', 'd-ansdeal3r.com', 1.0),
#   ('dansdeals.com', 'dansdeàls.com', 1.0),
#   ('dansdeals.com', 'daŋsđeals.com', 1.0),
#   ('dansdeals.com', 'dånsdëaĺs.com', 1.0),
#   ('dansdeals.com', 'danşd-eals.com', 1.0),
#   ('dansdeals.com', 'Ƌan-sdeäls.com', 1.0),
#   ('dansdeals.com', 'eaņsdeal3.com', 1.0),
#   ('okajax.com', 'okajaxq.com', 1.0),
#   ('okajax.com', 'okajaxww.com', 1.0),
#   ('okajax.com', 'okaajaxwf.com', 1.0),
#   ('okajax.com', 'okajaẍ.com', 1.0),
#   ('okajax.com', 'oķajaẍ.com', 1.0),
#   ('okajax.com', 'oķâjâx.com', 1.0),
#   ('okajax.com', '_ókajax.com', 1.0),
#   ('okajax.com', 'őkăja-x.com', 1.0),
#   ('okajax.com', 'okajcẋw.com', 1.0),
#   ('teenpornvideo.com', 'teenoprnvideo.com', 1.0),
#   ('teenpornvideo.com', 'deenporhvideo.com', 1.0),
#   ('teenpornvideo.com', 'deenpornvhde0.com', 1.0),
#   ('teenpornvideo.com', 'teeňpornvideo.com', 1.0),
#   ('teenpornvideo.com', 'teenpoŕnviƋeo.com', 1.0),
#   ('teenpornvideo.com', 'tĕenpoŕnvídeo.com', 1.0),
#   ('teenpornvideo.com', 'tednpörnvideo.com', 1.0),
#   ('teenpornvideo.com', 'têenƥkrnvideo.com', 1.0),
#   ('teenpornvideo.com', 'deenpornvĩddo.com', 1.0),
#   ('ca-alpesprovence.com', 'ca-alpgsprovence.com', 1.0),
#   ('ca-alpesprovence.com', 'ga-alpesprovenc_e.com', 1.0),
#   ('ca-alpesprovence.com', 'ca-qlpesproenc_e.com', 1.0),
#   ('ca-alpesprovence.com', 'ca-alpesprovencë.com', 1.0),
#   ('ca-alpesprovence.com', 'ċa-ãlpesprovence.com', 1.0),
#   ('ca-alpesprovence.com', 'ĉa-aĺpesprovenče.com', 1.0),
#   ('ca-alpesprovence.com', 'ca-alpespzoveńce.com', 1.0),
#   ('ca-alpesprovence.com', 'ca-alpesprovmncé.com', 1.0),
#   ('ca-alpesprovence.com', 'ca-àlpesprovenc_.com', 1.0),
#   ('absolutewrite.com', 'absolutewriteh.com', 1.0),
#   ('absolutewrite.com', 'acsolu7ewrite.com', 1.0),
#   ('absolutewrite.com', 'acsolutewrite.com', 1.0),
#   ('absolutewrite.com', 'àbsolutewrite.com', 1.0),
#   ('absolutewrite.com', 'aƀsoluťewrite.com', 1.0),
#   ('absolutewrite.com', 'aƀsoļutęwrite.com', 1.0),
#   ('absolutewrite.com', 'aibsolutewrĩte.com', 1.0),
#   ('absolutewrite.com', 'aƀsoluțewrtie.com', 1.0),
#   ('absolutewrite.com', 'acsoluvëwrite.com', 1.0),
#   ('skatewarehouse.com', 'skadewarehouse.com', 1.0),
#   ('skatewarehouse.com', 'sikatewarehouse.com', 1.0),
#   ('skatewarehouse.com', 'rlk-atewarehouse.com', 1.0),
#   ('skatewarehouse.com', 'skatewarehousĕ.com', 1.0),
#   ('skatewarehouse.com', 'škateẁarehouse.com', 1.0),
#   ('skatewarehouse.com', 'skateẁarĕħouse.com', 1.0),
#   ('skatewarehouse.com', 'skaʈewar-ehouse.com', 1.0),
#   ('skatewarehouse.com', 'sķatewărehou5e.com', 1.0),
#   ('skatewarehouse.com', 'slikątewarehouse.com', 1.0),
#   ('irorio.com', 'iroriok.com', 1.0),
#   ('irorio.com', 'i-rormo.com', 1.0),
#   ('irorio.com', 'i-roriosw.com', 1.0),
#   ('irorio.com', 'iròrio.com', 1.0),
#   ('irorio.com', 'ířȑorio.com', 1.0),
#   ('irorio.com', 'īřȑoȓio.com', 1.0),
#   ('irorio.com', 'yroȓio.com', 1.0),
#   ('irorio.com', '1ŕorio.com', 1.0),
#   ('irorio.com', 'i-ŗoio.com', 1.0),
#   ('xrea.com', 'xr-ea.com', 1.0),
#   ('xrea.com', 'xraek.com', 1.0),
#   ('xrea.com', 'xreaow.com', 1.0),
#   ('xrea.com', 'xřȑea.com', 1.0),
#   ('xrea.com', 'xřȑéa.com', 1.0),
#   ('xrea.com', '×rěā.com', 1.0),
#   ('xrea.com', 'xřȑec.com', 1.0),
#   ('xrea.com', 'zřȑèa.com', 1.0),
#   ('xrea.com', 'xzèak.com', 1.0),
#   ('l-tike.com', 'i-tike.com', 1.0),
#   ('l-tike.com', 'l-tikevr.com', 1.0),
#   ('l-tike.com', 'l-4ikevt.com', 1.0),
#   ('l-tike.com', 'l-tikë.com', 1.0),
#   ('l-tike.com', 'ł-ťike.com', 1.0),
#   ('l-tike.com', 'ŀ-tiķé.com', 1.0),
#   ('l-tike.com', 'l-tikğ.com', 1.0),
#   ('l-tike.com', 'l-tílće.com', 1.0),
#   ('l-tike.com', 'l-tikeṿ.com', 1.0),
#   ('h-cdn.com', 'h-cdnx.com', 1.0),
#   ('h-cdn.com', 'h-c_dn_.com', 1.0),
#   ('h-cdn.com', 'h-c_dinq.com', 1.0),
#   ('h-cdn.com', 'h-cdn.com', 1.0),
#   ('h-cdn.com', 'ĥ-ćdn.com', 1.0),
#   ('h-cdn.com', 'ħ-cƌŋ.com', 1.0),
#   ('h-cdn.com', 'ļ-cdn.com', 1.0),
#   ('h-cdn.com', 'h-cƌñj.com', 1.0),
#   ('h-cdn.com', 'h-c_Ƌnv.com', 1.0),
#   ('cocolog-nifty.com', 'coc_olog-nifty.com', 1.0),
#   ('cocolog-nifty.com', 'cocoloog-rifty.com', 1.0),
#   ('cocolog-nifty.com', 'coocoloo-gnifty.com', 1.0),
#   ('cocolog-nifty.com', 'cocoľog-nifty.com', 1.0),
#   ('cocolog-nifty.com', 'ĉocoľog-nifty.com', 1.0),
#   ('cocolog-nifty.com', 'ċòcolog-nifţy.com', 1.0),
#   ('cocolog-nifty.com', 'cocoloģ-nigty.com', 1.0),
#   ('cocolog-nifty.com', 'cõcolog-nifťq.com', 1.0),
#   ('cocolog-nifty.com', 'cočoloog-n-ifty.com', 1.0),
#   ('bill4time.com', 'bill47ime.com', 1.0),
#   ('bill4time.com', 'bill4t_ie.com', 1.0),
#   ('bill4time.com', 'billt4ia.com', 1.0),
#   ('bill4time.com', 'ƀill4time.com', 1.0),
#   ('bill4time.com', 'bilŀ4tiɱe.com', 1.0),
#   ('bill4time.com', 'bĭlŀ4time.com', 1.0),
#   ('bill4time.com', 'bill4timeĵ.com', 1.0),
#   ('bill4time.com', 'bíll4ʈiem.com', 1.0),
#   ('bill4time.com', 'bıllt4ie.com', 1.0),
#   ('uho.com', 'uh_o.com', 1.0),
#   ('uho.com', 'u_oh.com', 1.0),
#   ('uho.com', 'uo1h.com', 1.0),
#   ('uho.com', 'uĥo.com', 1.0),
#   ('uho.com', 'ûĥo.com', 1.0),
#   ('uho.com', 'ũĥő.com', 1.0),
#   ('uho.com', 'uħon.com', 1.0),
#   ('uho.com', 'uĥoɋ.com', 1.0),
#   ('uho.com', 'uohṿ.com', 1.0),
#   ('actuallno.com', 'actua1lno.com', 1.0),
#   ('actuallno.com', 'a_ctuallnop.com', 1.0),
#   ('actuallno.com', 'a_ctuadl_no.com', 1.0),
#   ('actuallno.com', 'āctuallno.com', 1.0),
#   ('actuallno.com', 'actuąllnö.com', 1.0),
#   ('actuallno.com', 'actűalĺño.com', 1.0),
#   ('actuallno.com', 'ăctuallnou.com', 1.0),
#   ('actuallno.com', 'açŧuallnom.com', 1.0),
#   ('actuallno.com', 'a_gtuăllno.com', 1.0),
#   ('nh-hoteles.com', 'nh-hmteles.com', 1.0),
#   ('nh-hoteles.com', 'nh-hotelush.com', 1.0),
#   ('nh-hoteles.com', 'nh-notelesh.com', 1.0),
#   ('nh-hoteles.com', 'nh-hoteľes.com', 1.0),
#   ('nh-hoteles.com', 'ņh-hoţeles.com', 1.0),
#   ('nh-hoteles.com', 'nh-hoťěļes.com', 1.0),
#   ('nh-hoteles.com', 'nh-ħotelus.com', 1.0),
#   ('nh-hoteles.com', 'nħ-ohțeles.com', 1.0),
#   ('nh-hoteles.com', 'nh-hoʈelerh.com', 1.0),
#   ('thecompleteuniversityguide.com', 'thecompleteuniversityguidea.com', 1.0),
#   ('thecompleteuniversityguide.com', 'thecompleteluiversityguide.com', 1.0),
#   ('thecompleteuniversityguide.com', 'thecompleteuliversitygiudef.com', 1.0),
#   ('thecompleteuniversityguide.com', 'thecompleteunîversityguide.com', 1.0),
#   ('thecompleteuniversityguide.com', 'tħecompleteuniversityguiƌe.com', 1.0),
#   ('thecompleteuniversityguide.com', 'thecomplēteuniṿersityguiđe.com', 1.0),
#   ('thecompleteuniversityguide.com', 'thecompleteunlverşityguide.com', 1.0),
#   ('thecompleteuniversityguide.com', 'tĥėcompleteuniversitygiude.com', 1.0),
#   ('thecompleteuniversityguide.com', 'thěcomp_leteuliversityguide.com', 1.0),
#   ('catshare.com', 'catsharm.com', 1.0),
#   ('catshare.com', 'cats-hara.com', 1.0),
#   ('catshare.com', 'cats_-hareo.com', 1.0),
#   ('catshare.com', 'catshăre.com', 1.0),
#   ('catshare.com', 'catshārė.com', 1.0),
#   ('catshare.com', 'catșħarė.com', 1.0),
#   ('catshare.com', 'catshâare.com', 1.0),
#   ('catshare.com', 'cațtsĥare.com', 1.0),
#   ('catshare.com', 'catq-haɍe.com', 1.0),
#   ('allo-pages.com', 'allo-pagesy.com', 1.0),
#   ('allo-pages.com', 'allo-pgaesk.com', 1.0),
#   ('allo-pages.com', 'allo-rgaesu.com', 1.0),
#   ('allo-pages.com', 'allo-päges.com', 1.0),
#   ('allo-pages.com', 'ałlo-pageş.com', 1.0),
#   ('allo-pages.com', 'allo-þāġes.com', 1.0),
#   ('allo-pages.com', 'ąllo-pagesq.com', 1.0),
#   ('allo-pages.com', 'allo_-păges.com', 1.0),
#   ('allo-pages.com', 'qllo-ƥgaes.com', 1.0),
#   ('weedi.com', '_weedi.com', 1.0),
#   ('weedi.com', 'weeeiu.com', 1.0),
#   ('weedi.com', 'we_eeih.com', 1.0),
#   ('weedi.com', 'weedĭ.com', 1.0),
#   ('weedi.com', 'ẉéedi.com', 1.0),
#   ('weedi.com', 'weěƌí.com', 1.0),
#   ('weedi.com', 'weëedi.com', 1.0),
#   ('weedi.com', 'gęeƋi.com', 1.0),
#   ('weedi.com', 'weĕei.com', 1.0),
#   ('counseling.com', 'ounseling.com', 1.0),
#   ('counseling.com', 'coounseliing.com', 1.0),
#   ('counseling.com', 'counselini6.com', 1.0),
#   ('counseling.com', 'counsĕling.com', 1.0),
#   ('counseling.com', 'counselıňg.com', 1.0),
#   ('counseling.com', 'coúŋşeling.com', 1.0),
#   ('counseling.com', 'counšelin6.com', 1.0),
#   ('counseling.com', 'cöŭns-eling.com', 1.0),
#   ('counseling.com', 'cousnėliing.com', 1.0),
#   ('couponbank.com', 'coupofbank.com', 1.0),
#   ('couponbank.com', 'cou_pobnank.com', 1.0),
#   ('couponbank.com', 'ccoupbonank.com', 1.0),
#   ('couponbank.com', 'cōuponbank.com', 1.0),
#   ('couponbank.com', 'coµpoñbank.com', 1.0),
#   ('couponbank.com', 'couþonƀanķ.com', 1.0),
#   ('couponbank.com', 'coupôrbank.com', 1.0),
#   ('couponbank.com', 'ċoupknbanķ.com', 1.0),
#   ('couponbank.com', 'coupobnãnkl.com', 1.0),
#   ('bedetheque.com', 'bedethequec.com', 1.0),
#   ('bedetheque.com', 'bedet-hequef.com', 1.0),
#   ('bedetheque.com', 'bebet-hdque.com', 1.0),
#   ('bedetheque.com', 'bedeťheque.com', 1.0),
#   ('bedetheque.com', 'beƌetheԛue.com', 1.0),
#   ('bedetheque.com', 'bēdeŧheqȕe.com', 1.0),
#   ('bedetheque.com', 'bedeţhequep.com', 1.0),
#   ('bedetheque.com', 'budetĥęque.com', 1.0),
#   ('bedetheque.com', 'bddět-heque.com', 1.0),
#   ('worldsoccershop.com', 'worldsoccershopj.com', 1.0),
#   ('worldsoccershop.com', 'worndsoccershopp.com', 1.0),
#   ('worldsoccershop.com', 'worlsoccershoppb.com', 1.0),
#   ('worldsoccershop.com', 'worldsoccershoƥ.com', 1.0),
#   ('worldsoccershop.com', 'worldsóccerʂhop.com', 1.0),
#   ('worldsoccershop.com', 'worlđsoçcërshop.com', 1.0),
#   ('worldsoccershop.com', 'worldsocćershop_.com', 1.0),
#   ('worldsoccershop.com', 'worlđsôccershp.com', 1.0),
#   ('worldsoccershop.com', 'Ŵroldsoccershopp.com', 1.0),
#   ('hdfree.com', 'hefree.com', 1.0),
#   ('hdfree.com', 'hddrree.com', 1.0),
#   ('hdfree.com', 'edree.com', 1.0),
#   ('hdfree.com', 'hdfreė.com', 1.0),
#   ('hdfree.com', 'hďfȓee.com', 1.0),
#   ('hdfree.com', 'hďſreę.com', 1.0),
#   ('hdfree.com', 'hdſr-ee.com', 1.0),
#   ('hdfree.com', 'hđƒreek.com', 1.0),
#   ('hdfree.com', 'hdƌreev.com', 1.0),
#   ('optibet.com', 'optibetc.com', 1.0),
#   ('optibet.com', 'opthebt.com', 1.0),
#   ('optibet.com', 'opthlb-et.com', 1.0),
#   ('optibet.com', 'oðtibet.com', 1.0),
#   ('optibet.com', 'ōpťibet.com', 1.0),
#   ('optibet.com', 'oðtiƀĕt.com', 1.0),
#   ('optibet.com', 'óptiet.com', 1.0),
#   ('optibet.com', 'opțĩibet.com', 1.0),
#   ('optibet.com', 'optnbeť.com', 1.0),
#   ('solecsy.com', 'oslecsy.com', 1.0),
#   ('solecsy.com', 'soleecsyp.com', 1.0),
#   ('solecsy.com', 'rolmcsyp.com', 1.0),
#   ('solecsy.com', 'sölecsy.com', 1.0),
#   ('solecsy.com', 'solėçsy.com', 1.0),
#   ('solecsy.com', 'soļeçʂy.com', 1.0),
#   ('solecsy.com', 'soluċsy.com', 1.0),
#   ('solecsy.com', 'șoŀlecsy.com', 1.0),
#   ('solecsy.com', 'solĕcsypj.com', 1.0),
#   ('thenewkhalij.com', 'thenewkhalijp.com', 1.0),
#   ('thenewkhalij.com', 'txenewhalij.com', 1.0),
#   ('thenewkhalij.com', 'txnewkhilij.com', 1.0),
#   ('thenewkhalij.com', 'thenewkhaliĵ.com', 1.0),
#   ('thenewkhalij.com', 'thěnewķhalij.com', 1.0),
#   ('thenewkhalij.com', 'ŧhenewkhałĭj.com', 1.0),
#   ('thenewkhalij.com', 'tĥenewkhalijz.com', 1.0),
#   ('thenewkhalij.com', 'tĥenewkhālijt.com', 1.0),
#   ('thenewkhalij.com', 'ţxenewkhalijk.com', 1.0),
#   ('tanea.com', 'tamea.com', 1.0),
#   ('tanea.com', 'taean.com', 1.0),
#   ('tanea.com', 'taaay.com', 1.0),
#   ('tanea.com', 'tanėa.com', 1.0),
#   ('tanea.com', 'tàneâ.com', 1.0),
#   ('tanea.com', 'ťåneà.com', 1.0),
#   ('tanea.com', 'ŧan-ea.com', 1.0),
#   ('tanea.com', 'taŉeā_.com', 1.0),
#   ('tanea.com', 'taeāi.com', 1.0),
#   ('boacompra.com', 'boacorrpra.com', 1.0),
#   ('boacompra.com', 'bo-ccompra.com', 1.0),
#   ('boacompra.com', 'bocgopmra.com', 1.0),
#   ('boacompra.com', 'bóacompra.com', 1.0),
#   ('boacompra.com', 'boàcômpra.com', 1.0),
#   ('boacompra.com', 'boâcompřȑă.com', 1.0),
#   ('boacompra.com', 'boa_çompra.com', 1.0),
#   ('boacompra.com', '8oâcomprå.com', 1.0),
#   ('boacompra.com', 'boĉco_mpra.com', 1.0),
#   ('adams12.com', 'a-dams12.com', 1.0),
#   ('adams12.com', 'adahs12.com', 1.0),
#   ('adams12.com', 'adansi2t.com', 1.0),
#   ('adams12.com', 'adâms12.com', 1.0),
#   ('adams12.com', 'adăɱs12.com', 1.0),
#   ('adams12.com', 'ádaɱs12.com', 1.0),
#   ('adams12.com', 'aađms12.com', 1.0),
#   ('adams12.com', 'adaɱs12ĵ.com', 1.0),
#   ('adams12.com', 'adăns12e.com', 1.0),
#   ('internethaber.com', 'inteznethaber.com', 1.0),
#   ('internethaber.com', 'internetjaberg.com', 1.0),
#   ('internethaber.com', 'ynternetj4ber.com', 1.0),
#   ('internethaber.com', 'internēthaber.com', 1.0),
#   ('internethaber.com', 'internethabēȓ.com', 1.0),
#   ('internethaber.com', 'intēŗnethaƀer.com', 1.0),
#   ('internethaber.com', 'intermethabeɍ.com', 1.0),
#   ('internethaber.com', 'imţernethaƀer.com', 1.0),
#   ('internethaber.com', 'internetĵabert.com', 1.0),
#   ('caveofprogramming.com', 'caveofpr-ogramming.com', 1.0),
#   ('caveofprogramming.com', 'c_aveofpvogramming.com', 1.0),
#   ('caveofprogramming.com', 'caveof-pvogrammingz.com', 1.0),
#   ('caveofprogramming.com', 'caveofprogrammíng.com', 1.0),
#   ('caveofprogramming.com', 'caveøfprogrammiņg.com', 1.0),
#   ('caveofprogramming.com', 'cáveofprøgɍamming.com', 1.0),
#   ('caveofprogramming.com', 'cavemƒprogramming.com', 1.0),
#   ('caveofprogramming.com', 'cãvegfproġramming.com', 1.0),
#   ('caveofprogramming.com', 'caveofpvoĝrammingx.com', 1.0),
#   ('onlinemediamasters.com', 'onlinemedliamasters.com', 1.0),
#   ('onlinemediamasters.com', 'onlinemediamasters.com', 1.0),
#   ('onlinemediamasters.com', 'onlioemedianasters.com', 1.0),
#   ('onlinemediamasters.com', 'onliŋemediamasters.com', 1.0),
#   ('onlinemediamasters.com', 'onlinemediämastĕrs.com', 1.0),
#   ('onlinemediamasters.com', 'onłinemêdĩamasters.com', 1.0),
#   ('onlinemediamasters.com', 'onlinelediamasterş.com', 1.0),
#   ('onlinemediamasters.com', 'oŋ-linèmediamasters.com', 1.0),
#   ('onlinemediamasters.com', 'onlinèmgdianasters.com', 1.0),
#   ('domesticsale.com', 'domesticssale.com', 1.0),
#   ('domesticsale.com', 'domesticsaleqe.com', 1.0),
#   ('domesticsale.com', 'do_mesticsaley.com', 1.0),
#   ('domesticsale.com', 'ďomesticsale.com', 1.0),
#   ('domesticsale.com', 'ďomesticsàle.com', 1.0),
#   ('domesticsale.com', 'dőměstïcsale.com', 1.0),
#   ('domesticsale.com', 'đomesticsile.com', 1.0),
#   ('domesticsale.com', 'dolestičśale.com', 1.0),
#   ('domesticsale.com', 'dometicsaleԛ.com', 1.0),
#   ('polymeran.com', 'polymeranj.com', 1.0),
#   ('polymeran.com', 'po-_lymeran.com', 1.0),
#   ('polymeran.com', 'pm_ylmeran.com', 1.0),
#   ('polymeran.com', 'þolymeran.com', 1.0),
#   ('polymeran.com', 'polýɱeran.com', 1.0),
#   ('polymeran.com', 'pøłẏmeran.com', 1.0),
#   ('polymeran.com', 'podyɱeran.com', 1.0),
#   ('polymeran.com', 'podẏɱeran.com', 1.0),
#   ('polymeran.com', 'po_lymer4ñ.com', 1.0),
#   ('wcu.com', 'wc.com', 1.0),
#   ('wcu.com', 'wcqs.com', 1.0),
#   ('wcu.com', 'wco.com', 1.0),
#   ('wcu.com', 'wċu.com', 1.0),
#   ('wcu.com', 'wċŭ.com', 1.0),
#   ('wcu.com', 'ẉĉū.com', 1.0),
#   ('wcu.com', 'vcų.com', 1.0),
#   ('wcu.com', 'wçuṿ.com', 1.0),
#   ('wcu.com', 'wcqĵ.com', 1.0),
#   ('keng94.com', 'keng9_4.com', 1.0),
#   ('keng94.com', 'keg94w.com', 1.0),
#   ('keng94.com', 'keg9w.com', 1.0),
#   ('keng94.com', 'keng94.com', 1.0),
#   ('keng94.com', 'ķeng94.com', 1.0),
#   ('keng94.com', 'ķeŋğ94.com', 1.0),
#   ('keng94.com', 'keng94k.com', 1.0),
#   ('keng94.com', 'keńnĝ94.com', 1.0),
#   ('keng94.com', 'k_eng94ẁ.com', 1.0),
#   ('amylynnandrews.com', 'amylynnandres.com', 1.0),
#   ('amylynnandrews.com', 'amyynlnandrews.com', 1.0),
#   ('amylynnandrews.com', 'amyy-lnnandrewsw.com', 1.0),
#   ('amylynnandrews.com', 'āmylynnandrews.com', 1.0),
#   ('amylynnandrews.com', 'amylynnăndreẇs.com', 1.0),
#   ('amylynnandrews.com', 'aɱyłynnaŋdrews.com', 1.0),
#   ('amylynnandrews.com', 'amylynnan-dreẅs.com', 1.0),
#   ('amylynnandrews.com', 'amìlynnanďrews.com', 1.0),
#   ('amylynnandrews.com', 'amylynnandrėws.com', 1.0),
#   ('wp-kama.com', 'wp-kamay.com', 1.0),
#   ('wp-kama.com', 'wq-kame.com', 1.0),
#   ('wp-kama.com', 'wp-imae.com', 1.0),
#   ('wp-kama.com', 'wp-kaɱa.com', 1.0),
#   ('wp-kama.com', 'wp-kaɱa.com', 1.0),
#   ('wp-kama.com', 'wp-ķâmå.com', 1.0),
#   ('wp-kama.com', 'wp-kamap.com', 1.0),
#   ('wp-kama.com', 'ẇð-kaea.com', 1.0),
#   ('wp-kama.com', 'ẇp-kamez.com', 1.0),
#   ('templaza.com', 'tem-plaza.com', 1.0),
#   ('templaza.com', 'tepmlaza_.com', 1.0),
#   ('templaza.com', '4empdaza_.com', 1.0),
#   ('templaza.com', 'templâza.com', 1.0),
#   ('templaza.com', 'temþlaẓa.com', 1.0),
#   ('templaza.com', 'tęmðlaẓa.com', 1.0),
#   ('templaza.com', 'țemplaze.com', 1.0),
#   ('templaza.com', '4empläzã.com', 1.0),
#   ('templaza.com', 'templaza_f.com', 1.0),
#   ('dreamlandjewelry.com', 'dreamlandjeweelry.com', 1.0),
#   ('dreamlandjewelry.com', 'd_reamlandjeweiry.com', 1.0),
#   ('dreamlandjewelry.com', 'dre-amlandzeweiry.com', 1.0),
#   ('dreamlandjewelry.com', 'dreamlanđjewelry.com', 1.0),
#   ('dreamlandjewelry.com', 'dreamlanđjewelŕy.com', 1.0),
#   ('dreamlandjewelry.com', 'dręąmlandjeweļry.com', 1.0),
#   ('dreamlandjewelry.com', 'dreamlandjeweľrys.com', 1.0),
#   ('dreamlandjewelry.com', 'ďreamlandjewēlryg.com', 1.0),
#   ('dreamlandjewelry.com', 'đreamlandjeweirii.com', 1.0),
#   ('prnoticias.com', 'prnoticiaso.com', 1.0),
#   ('prnoticias.com', 'prrotiicas.com', 1.0),
#   ('prnoticias.com', 'prrgt_icias.com', 1.0),
#   ('prnoticias.com', 'prnòticias.com', 1.0),
#   ('prnoticias.com', 'ƥrnoțicias.com', 1.0),
#   ('prnoticias.com', 'prňóticiãs.com', 1.0),
#   ('prnoticias.com', 'ƥrooticias.com', 1.0),
#   ('prnoticias.com', 'þȓnoticyas.com', 1.0),
#   ('prnoticias.com', 'prrotic-įas.com', 1.0),
#   ('phumikhmer8.com', 'phumikhmer8.com', 1.0),
#   ('phumikhmer8.com', 'phmuikhmer8o.com', 1.0),
#   ('phumikhmer8.com', 'phmuikh_mer8t.com', 1.0),
#   ('phumikhmer8.com', 'phuɱikhmer8.com', 1.0),
#   ('phumikhmer8.com', 'pħumikĥmer8.com', 1.0),
#   ('phumikhmer8.com', 'phuɱikhmęr8.com', 1.0),
#   ('phumikhmer8.com', 'phumīkhmer8d.com', 1.0),
#   ('phumikhmer8.com', 'pħumikhmeɍ_8.com', 1.0),
#   ('phumikhmer8.com', 'plmuikhmĕr8.com', 1.0),
#   ('vl.com', 'vln.com', 1.0),
#   ('vl.com', 'lvi.com', 1.0),
#   ('vl.com', 'vlo.com', 1.0),
#   ('vl.com', 'vľ.com', 1.0),
#   ('vl.com', 'ṽŀ.com', 1.0),
#   ('vl.com', 'ṿľ.com', 1.0),
#   ('vl.com', 'vĺd.com', 1.0),
#   ('vl.com', 'ṽļt.com', 1.0),
#   ('vl.com', 'ļ.com', 1.0),
#   ('akhbarbank.com', 'akhbasbank.com', 1.0),
#   ('akhbarbank.com', 'qkhbarbankq.com', 1.0),
#   ('akhbarbank.com', 'qkhbarrbaok.com', 1.0),
#   ('akhbarbank.com', 'aķhbarbank.com', 1.0),
#   ('akhbarbank.com', 'akhbarƀaňk.com', 1.0),
#   ('akhbarbank.com', 'ăķhbaȓbank.com', 1.0),
#   ('akhbarbank.com', 'akhb-ąrbank.com', 1.0),
#   ('akhbarbank.com', 'qķhbarbańk.com', 1.0),
#   ('akhbarbank.com', 'qķhbarbankn.com', 1.0),
#   ('blackberryvietnam.com', 'blackberryvietnem.com', 1.0),
#   ('blackberryvietnam.com', 'bblackberryvietnamr.com', 1.0),
#   ('blackberryvietnam.com', 'blackberryvietnamrn.com', 1.0),
#   ('blackberryvietnam.com', 'blackberryvîetnam.com', 1.0),
#   ('blackberryvietnam.com', 'blackbeŗryviétnam.com', 1.0),
#   ('blackberryvietnam.com', 'bląckbeŕryṿietnam.com', 1.0),
#   ('blackberryvietnam.com', 'blacķberryvaetnam.com', 1.0),
#   ('blackberryvietnam.com', 'b_làckberryvietnaɱ.com', 1.0),
#   ('blackberryvietnam.com', 'blackbe_rɍyvietnamr.com', 1.0),
#   ('popnetwork.com', 'popnetworkj.com', 1.0),
#   ('popnetwork.com', 'opnetwork_.com', 1.0),
#   ('popnetwork.com', 'popn-etork_.com', 1.0),
#   ('popnetwork.com', 'popnetwoɍk.com', 1.0),
#   ('popnetwork.com', 'poþnetworķ.com', 1.0),
#   ('popnetwork.com', 'popnëtwŏrķ.com', 1.0),
#   ('popnetwork.com', 'poƥn-etwork.com', 1.0),
#   ('popnetwork.com', 'þopnetwoŗ.com', 1.0),
#   ('popnetwork.com', 'pøpnetwkrk_.com', 1.0),
#   ('firsttennessee.com', 'firsttgnnessee.com', 1.0),
#   ('firsttennessee.com', 'firsttenn_e5see.com', 1.0),
#   ('firsttennessee.com', 'firrsttenn_esseeb.com', 1.0),
#   ('firsttennessee.com', 'firsttenneŝsee.com', 1.0),
#   ('firsttennessee.com', 'fiŗstŧennessee.com', 1.0),
#   ('firsttennessee.com', 'firʂtţenneşsee.com', 1.0),
#   ('firsttennessee.com', 'firstʈennessed.com', 1.0),
#   ('firsttennessee.com', 'ƒirstteńmessee.com', 1.0),
#   ('firsttennessee.com', 'firşt7enn_essee.com', 1.0),
#   ('qcloud.com', 'qcoud.com', 1.0),
#   ('qcloud.com', 'qg-loud.com', 1.0),
#   ('qcloud.com', 'qc-lo-udk.com', 1.0),
#   ('qcloud.com', 'qćloud.com', 1.0),
#   ('qcloud.com', 'qčlouƋ.com', 1.0),
#   ('qcloud.com', 'qcłöuđ.com', 1.0),
#   ('qcloud.com', 'qčloudh.com', 1.0),
#   ('qcloud.com', '_ɋcľoud.com', 1.0),
#   ('qcloud.com', 'qc-lòudl.com', 1.0),
#   ('pay-click.com', 'pa-click.com', 1.0),
#   ('pay-click.com', 'pay-cdick_.com', 1.0),
#   ('pay-click.com', 'pay-cidcky.com', 1.0),
#   ('pay-click.com', 'páy-click.com', 1.0),
#   ('pay-click.com', 'ƥaŷ-click.com', 1.0),
#   ('pay-click.com', 'þay-clĩčk.com', 1.0),
#   ('pay-click.com', 'pay-c-lick.com', 1.0),
#   ('pay-click.com', 'paymćŀick.com', 1.0),
#   ('pay-click.com', 'pay-ĉdicki.com', 1.0),
#   ('dk1024.com', 'bk1024.com', 1.0),
#   ('dk1024.com', 'dk10z6.com', 1.0),
#   ('dk1024.com', 'dk10_z4g.com', 1.0),
#   ('dk1024.com', 'dķ1024.com', 1.0),
#   ('dk1024.com', 'dk1024.com', 1.0),
#   ('dk1024.com', 'ƌķ1024.com', 1.0),
#   ('dk1024.com', 'đk1824.com', 1.0),
#   ('dk1024.com', 'ď_k1024.com', 1.0),
#   ('dk1024.com', 'ďk1024.com', 1.0),
#   ('bikesdirect.com', 'bikesdirgct.com', 1.0),
#   ('bikesdirect.com', 'bikusdirec4.com', 1.0),
#   ('bikesdirect.com', 'bikes_dirdc4.com', 1.0),
#   ('bikesdirect.com', 'bıkesdirect.com', 1.0),
#   ('bikesdirect.com', 'bikesdiɍėct.com', 1.0),
#   ('bikesdirect.com', 'ƀikešdirěct.com', 1.0),
#   ('bikesdirect.com', 'bikesdirēcta.com', 1.0),
#   ('bikesdirect.com', 'bikesdiŗecŧb.com', 1.0),
#   ('bikesdirect.com', 'bikesdiiɍec4.com', 1.0),
#   ('blinn.com', 'blnin.com', 1.0),
#   ('blinn.com', 'linnz.com', 1.0),
#   ('blinn.com', 'lb_innz.com', 1.0),
#   ('blinn.com', 'ƀlinn.com', 1.0),
#   ('blinn.com', 'bĺįnn.com', 1.0),
#   ('blinn.com', 'ƀĺïnn.com', 1.0),
#   ('blinn.com', 'ƀl1nn.com', 1.0),
#   ('blinn.com', 'ƀľin-n.com', 1.0),
#   ('blinn.com', 'blilňz.com', 1.0),
#   ('meteofrance.com', 'meteofrancel.com', 1.0),
#   ('meteofrance.com', 'meteo-frcnce.com', 1.0),
#   ('meteofrance.com', 'metmo-frane.com', 1.0),
#   ('meteofrance.com', 'meteofrănce.com', 1.0),
#   ('meteofrance.com', 'meteŏfrançe.com', 1.0),
#   ('meteofrance.com', 'mętēofraŉce.com', 1.0),
#   ('meteofrance.com', 'mefeoſrance.com', 1.0),
#   ('meteofrance.com', 'męteôfrancef.com', 1.0),
#   ('meteofrance.com', 'mete-o-france.com', 1.0),
#   ('virustotal.com', 'vivustotal.com', 1.0),
#   ('virustotal.com', 'vivusottal.com', 1.0),
#   ('virustotal.com', 'viursottam.com', 1.0),
#   ('virustotal.com', 'ṿirustotal.com', 1.0),
#   ('virustotal.com', 'vìrustotäl.com', 1.0),
#   ('virustotal.com', 'víɍuʂtotal.com', 1.0),
#   ('virustotal.com', 'virurtoțal.com', 1.0),
#   ('virustotal.com', 'virustoţaľb.com', 1.0),
#   ('virustotal.com', 'vírusotta_l.com', 1.0),
#   ('perpusnas.com', 'perqusnas.com', 1.0),
#   ('perpusnas.com', 'perpussna3.com', 1.0),
#   ('perpusnas.com', 'perpusnaa3.com', 1.0),
#   ('perpusnas.com', 'perpusŋas.com', 1.0),
#   ('perpusnas.com', 'perþuşnas.com', 1.0),
#   ('perpusnas.com', 'ðerpušŋas.com', 1.0),
#   ('perpusnas.com', 'þerpusncs.com', 1.0),
#   ('perpusnas.com', 'pęrpůsnasu.com', 1.0),
#   ('perpusnas.com', 'perpusná3a.com', 1.0),
#   ('gama.com', 'gcma.com', 1.0),
#   ('gama.com', '6amma.com', 1.0),
#   ('gama.com', '6ammaw.com', 1.0),
#   ('gama.com', 'gamä.com', 1.0),
#   ('gama.com', 'gäɱa.com', 1.0),
#   ('gama.com', 'ĝaɱâ.com', 1.0),
#   ('gama.com', 'ġala.com', 1.0),
#   ('gama.com', 'gàēa.com', 1.0),
#   ('gama.com', '6aɱe.com', 1.0),
#   ('o-kosmoz.com', '_o-kosmoz.com', 1.0),
#   ('o-kosmoz.com', 'g-lkosmoz.com', 1.0),
#   ('o-kosmoz.com', 'o-ikosmor.com', 1.0),
#   ('o-kosmoz.com', 'o-kosmòz.com', 1.0),
#   ('o-kosmoz.com', 'o-kośɱoz.com', 1.0),
#   ('o-kosmoz.com', 'ø-koșɱoz.com', 1.0),
#   ('o-kosmoz.com', 'o-kosmozn.com', 1.0),
#   ('o-kosmoz.com', 'o-koş_möz.com', 1.0),
#   ('o-kosmoz.com', 'o-_lkosmŏz.com', 1.0),
#   ('markets.com', 'mrakets.com', 1.0),
#   ('markets.com', 'marke_tsn.com', 1.0),
#   ('markets.com', 'market-snz.com', 1.0),
#   ('markets.com', 'ɱarkets.com', 1.0),
#   ('markets.com', 'márķets.com', 1.0),
#   ('markets.com', 'mäȓketʂ.com', 1.0),
#   ('markets.com', 'marķets.com', 1.0),
#   ('markets.com', 'marķetŝe.com', 1.0),
#   ('markets.com', 'mar_keŧsn.com', 1.0),
#   ('headlinepolitics.com', 'headlinepolitic-s.com', 1.0),
#   ('headlinepolitics.com', 'lheadlinepoliticst.com', 1.0),
#   ('headlinepolitics.com', 'headlinepoliiticstp.com', 1.0),
#   ('headlinepolitics.com', 'headlinêpolitics.com', 1.0),
#   ('headlinepolitics.com', 'headľiñepolitics.com', 1.0),
#   ('headlinepolitics.com', 'headlînepoĺiticś.com', 1.0),
#   ('headlinepolitics.com', 'hēadlinepoliticsp.com', 1.0),
#   ('headlinepolitics.com', 'healinĕpoliʈics.com', 1.0),
#   ('headlinepolitics.com', 'headlinepolitcŝt.com', 1.0),
#   ('pointclicktrack.com', 'pointclickktrack.com', 1.0),
#   ('pointclicktrack.com', 'ponitclickvrack.com', 1.0),
#   ('pointclicktrack.com', 'opintclickvracku.com', 1.0),
#   ('pointclicktrack.com', 'pôintclicktrack.com', 1.0),
#   ('pointclicktrack.com', 'poìntclicktɍack.com', 1.0),
#   ('pointclicktrack.com', 'põĩntclìcktrack.com', 1.0),
#   ('pointclicktrack.com', 'pointclĭcktracks.com', 1.0),
#   ('pointclicktrack.com', 'tointclicktɍacķ.com', 1.0),
#   ('pointclicktrack.com', 'pŏin7clickvrack.com', 1.0),
#   ('mybrandrewardsurveys.com', 'miibrandrewardsurveys.com', 1.0),
#   ('mybrandrewardsurveys.com', 'iybrandrewardsurveysy.com', 1.0),
#   ('mybrandrewardsurveys.com', 'mybranderwardsurveysya.com', 1.0),
#   ('mybrandrewardsurveys.com', 'mybrandrewardsuřȑveys.com', 1.0),
#   ('mybrandrewardsurveys.com', 'mybrandrewardșurvėys.com', 1.0),
#   ('mybrandrewardsurveys.com', 'myƀrandręwardsurveŷs.com', 1.0),
#   ('mybrandrewardsurveys.com', 'mybrandre_wârdsurveys.com', 1.0),
#   ('mybrandrewardsurveys.com', 'mybrcndrewârdsurveÿs.com', 1.0),
#   ('mybrandrewardsurveys.com', 'mybraņdbewardsurveysy.com', 1.0),
#   ('monster-wiki.com', 'monsteer-wiki.com', 1.0),
#   ('monster-wiki.com', 'mnn_ster-wiki.com', 1.0),
#   ('monster-wiki.com', 'mon_ster-wiki_f.com', 1.0),
#   ('monster-wiki.com', 'mönster-wiki.com', 1.0),
#   ('monster-wiki.com', 'mönster-wiķi.com', 1.0),
#   ('monster-wiki.com', 'monștér-ẅiki.com', 1.0),
#   ('monster-wiki.com', 'monʂter-wwiki.com', 1.0),
#   ('monster-wiki.com', 'ɱonşter-wik1.com', 1.0),
#   ('monster-wiki.com', 'mon_śter-wikki.com', 1.0),
#   ('magazineworld.com', 'magazneworld.com', 1.0),
#   ('magazineworld.com', 'magaz_ineworlld.com', 1.0),
#   ('magazineworld.com', 'magaz1newor-lld.com', 1.0),
#   ('magazineworld.com', 'magăzineworld.com', 1.0),
#   ('magazineworld.com', 'magażineworlƋ.com', 1.0),
#   ('magazineworld.com', 'magazínewořȑŀd.com', 1.0),
#   ('magazineworld.com', 'magazirëworld.com', 1.0),
#   ('magazineworld.com', 'maga2inewòřȑld.com', 1.0),
#   ('magazineworld.com', 'māgazineworllt.com', 1.0),
#   ('zhayanwang.com', 'zhayafwang.com', 1.0),
#   ('zhayanwang.com', 'zhayam7ang.com', 1.0),
#   ('zhayanwang.com', 'zhayamgangv.com', 1.0),
#   ('zhayanwang.com', 'zhàyanwang.com', 1.0),
#   ('zhayanwang.com', 'ẓhâyanwang.com', 1.0),
#   ('zhayanwang.com', 'zĥaẏanwanĝ.com', 1.0),
#   ('zhayanwang.com', 'zhayanwålg.com', 1.0),
#   ('zhayanwang.com', 'zh-ayanwāng.com', 1.0),
#   ('zhayanwang.com', 'zha9amwâng.com', 1.0),
#   ('kbtx.com', 'kbtx_.com', 1.0),
#   ('kbtx.com', 'k-bttx.com', 1.0),
#   ('kbtx.com', 'kbttyc.com', 1.0),
#   ('kbtx.com', 'kƀtx.com', 1.0),
#   ('kbtx.com', 'ķbțx.com', 1.0),
#   ('kbtx.com', 'ķƀʈx.com', 1.0),
#   ('kbtx.com', 'ķbbtx.com', 1.0),
#   ('kbtx.com', 'ķ8ŧx.com', 1.0),
#   ('kbtx.com', 'kbttẏ.com', 1.0),
#   ('bastainfo.com', 'bastain_fo.com', 1.0),
#   ('bastainfo.com', 'b5atainfo.com', 1.0),
#   ('bastainfo.com', 'baa5atinfo.com', 1.0),
#   ('bastainfo.com', 'bastainfò.com', 1.0),
#   ('bastainfo.com', 'baştainſo.com', 1.0),
#   ('bastainfo.com', 'baŝtăinſo.com', 1.0),
#   ('bastainfo.com', 'bastainbó.com', 1.0),
#   ('bastainfo.com', 'biștainſo.com', 1.0),
#   ('bastainfo.com', 'ba5ţainfok.com', 1.0),
#   ('booksonline.com', '8ooksonline.com', 1.0),
#   ('booksonline.com', 'bookksonlline.com', 1.0),
#   ('booksonline.com', 'booksoollinen.com', 1.0),
#   ('booksonline.com', 'boøksonline.com', 1.0),
#   ('booksonline.com', 'ƀooķsonline.com', 1.0),
#   ('booksonline.com', 'booksõňŀine.com', 1.0),
#   ('booksonline.com', 'bookśonlkne.com', 1.0),
#   ('booksonline.com', 'booksøņnine.com', 1.0),
#   ('booksonline.com', 'booķsonllnie.com', 1.0),
#   ('hackread.com', 'hckread.com', 1.0),
#   ('hackread.com', 'hackread.com', 1.0),
#   ('hackread.com', 'haccera.com', 1.0),
#   ('hackread.com', 'hacķread.com', 1.0),
#   ('hackread.com', 'hąckŗead.com', 1.0),
#   ('hackread.com', 'ĥacķreàd.com', 1.0),
#   ('hackread.com', 'hackreađo.com', 1.0),
#   ('hackread.com', 'hackreàdý.com', 1.0),
#   ('hackread.com', 'hącbread.com', 1.0),
#   ('livingathome.com', 'livhngathome.com', 1.0),
#   ('livingathome.com', 'livlgathome.com', 1.0),
#   ('livingathome.com', 'livngathmea.com', 1.0),
#   ('livingathome.com', 'livinġathome.com', 1.0),
#   ('livingathome.com', 'livingàthomę.com', 1.0),
#   ('livingathome.com', 'ŀivīngathomę.com', 1.0),
#   ('livingathome.com', 'living4thomĕ.com', 1.0),
#   ('livingathome.com', 'l1ṿingatĥome.com', 1.0),
#   ('livingathome.com', 'liungãthome.com', 1.0),
#   ('digitaleveuk.com', 'digitaleveuku.com', 1.0),
#   ('digitaleveuk.com', 'digitale6muk.com', 1.0),
#   ('digitaleveuk.com', 'dgiktale6euk.com', 1.0),
#   ('digitaleveuk.com', 'digitalevėuk.com', 1.0),
#   ('digitaleveuk.com', 'dîgïtaleveuk.com', 1.0),
#   ('digitaleveuk.com', 'đigitãlevęuk.com', 1.0),
#   ('digitaleveuk.com', 'digĩtalevek.com', 1.0),
#   ('digitaleveuk.com', 'digitąlleveuķ.com', 1.0),
#   ('digitaleveuk.com', 'diğitahe6euk.com', 1.0),
#   ('verify-email.com', 'verify-emaild.com', 1.0),
#   ('verify-email.com', 'verify-emailyo.com', 1.0),
#   ('verify-email.com', 'veriny-ennaily.com', 1.0),
#   ('verify-email.com', 'verify-emáil.com', 1.0),
#   ('verify-email.com', 'verify-emaiŀ.com', 1.0),
#   ('verify-email.com', 'veřȑiƒy-email.com', 1.0),
#   ('verify-email.com', 'verify-dmâil.com', 1.0),
#   ('verify-email.com', 'verify-email_.com', 1.0),
#   ('verify-email.com', 'ṿerify-erraily.com', 1.0),
#   ('jiaxiao123.com', 'j_iaxiao123.com', 1.0),
#   ('jiaxiao123.com', 'jyaxiiao123.com', 1.0),
#   ('jiaxiao123.com', 'jiayiio123.com', 1.0),
#   ('jiaxiao123.com', 'jîaxiao123.com', 1.0),
#   ('jiaxiao123.com', 'jiaxiào123.com', 1.0),
#   ('jiaxiao123.com', 'jiaxiaó123.com', 1.0),
#   ('jiaxiao123.com', 'jia×hao123.com', 1.0),
#   ('jiaxiao123.com', 'jiåxiaķ123.com', 1.0),
#   ('jiaxiao123.com', 'jiaxiioa123.com', 1.0),
#   ('jcpenney.com', 'jcpemey.com', 1.0),
#   ('jcpenney.com', 'jcpe_n_ney.com', 1.0),
#   ('jcpenney.com', 'jkpen_neym.com', 1.0),
#   ('jcpenney.com', 'jcpeŉney.com', 1.0),
#   ('jcpenney.com', 'jċpeŉney.com', 1.0),
#   ('jcpenney.com', 'jcþęnneŷ.com', 1.0),
#   ('jcpenney.com', 'jcpeñneyp.com', 1.0),
#   ('jcpenney.com', 'ĵcpennēyb.com', 1.0),
#   ('jcpenney.com', 'jcƥen_neyo.com', 1.0),
#   ('nzxt.com', 'nxxt.com', 1.0),
#   ('nzxt.com', 'nz-x7.com', 1.0),
#   ('nzxt.com', 'nzx3o.com', 1.0),
#   ('nzxt.com', 'ñzxt.com', 1.0),
#   ('nzxt.com', 'ŉẓxt.com', 1.0),
#   ('nzxt.com', 'ŉẓẍt.com', 1.0),
#   ('nzxt.com', 'nẑ8t.com', 1.0),
#   ('nzxt.com', 'nzẋtă.com', 1.0),
#   ('nzxt.com', 'nźx7e.com', 1.0),
#   ('foodierecipesearch.com', 'foodierecipesearchp.com', 1.0),
#   ('foodierecipesearch.com', 'foodierecipesearchl_.com', 1.0),
#   ('foodierecipesearch.com', 'foodierec10esearchl.com', 1.0),
#   ('foodierecipesearch.com', 'fõodierecipesearch.com', 1.0),
#   ('foodierecipesearch.com', 'fŏodierecipesearçh.com', 1.0),
#   ('foodierecipesearch.com', 'foŏdierecipeʂearĉh.com', 1.0),
#   ('foodierecipesearch.com', 'foodierecipesarčh.com', 1.0),
#   ('foodierecipesearch.com', 'foodiěrecipeseercħ.com', 1.0),
#   ('foodierecipesearch.com', 'foodierecipesė4rchl.com', 1.0),
#   ('ccc7.com', 'ccs7.com', 1.0),
#   ('ccc7.com', 'cccTm.com', 1.0),
#   ('ccc7.com', 'ccs-T.com', 1.0),
#   ('ccc7.com', 'ċcc7.com', 1.0),
#   ('ccc7.com', 'ćcĉ7.com', 1.0),
#   ('ccc7.com', 'ĉcč7.com', 1.0),
#   ('ccc7.com', 'ccċ7u.com', 1.0),
#   ('ccc7.com', 'cćc7k.com', 1.0),
#   ('ccc7.com', 'ccbṪ.com', 1.0),
#   ('noz.com', 'nz.com', 1.0),
#   ('noz.com', '_foz.com', 1.0),
#   ('noz.com', '_voz.com', 1.0),
#   ('noz.com', 'nőz.com', 1.0),
#   ('noz.com', 'ńôz.com', 1.0),
#   ('noz.com', 'ŋòź.com', 1.0),
#   ('noz.com', 'n0z.com', 1.0),
#   ('noz.com', 'nõzƒ.com', 1.0),
#   ('noz.com', 'góz.com', 1.0),
#   ('fborfw.com', 'fbor_fw.com', 1.0),
#   ('fborfw.com', 'fbofw.com', 1.0),
#   ('fborfw.com', 'f1borfw.com', 1.0),
#   ('fborfw.com', 'fborƒw.com', 1.0),
#   ('fborfw.com', 'fƀòrfw.com', 1.0),
#   ('fborfw.com', 'fbōȓƒw.com', 1.0),
#   ('fborfw.com', 'bƀorfw.com', 1.0),
#   ('fborfw.com', 'fƀőrfwn.com', 1.0),
#   ('fborfw.com', 'vbořȑfw.com', 1.0),
#   ('pixologic.com', 'pixologi.com', 1.0),
#   ('pixologic.com', 'pixodogc.com', 1.0),
#   ('pixologic.com', 'pix6logc.com', 1.0),
#   ('pixologic.com', 'pixòlogic.com', 1.0),
#   ('pixologic.com', 'pixøloĝic.com', 1.0),
#   ('pixologic.com', 'þixôlogīc.com', 1.0),
#   ('pixologic.com', 'píxolowic.com', 1.0),
#   ('pixologic.com', 'pixőlogicë.com', 1.0),
#   ('pixologic.com', 'ppixølogc.com', 1.0),
#   ('haclica.com', 'hac_lica.com', 1.0),
#   ('haclica.com', 'ieclica.com', 1.0),
#   ('haclica.com', 'huclical.com', 1.0),
#   ('haclica.com', 'hacliča.com', 1.0),
#   ('haclica.com', 'ĥaclića.com', 1.0),
#   ('haclica.com', 'hàclīcą.com', 1.0),
#   ('haclica.com', 'hacilća.com', 1.0),
#   ('haclica.com', 'hačl-ica.com', 1.0),
#   ('haclica.com', 'lecliça.com', 1.0),
#   ('incezt.com', 'inceztm.com', 1.0),
#   ('incezt.com', 'inceztf.com', 1.0),
#   ('incezt.com', 'inceztgxc.com', 1.0),
#   ('incezt.com', 'inçezt.com', 1.0),
#   ('incezt.com', 'îňcezt.com', 1.0),
#   ('incezt.com', 'įŋcęzt.com', 1.0),
#   ('incezt.com', 'inceźte.com', 1.0),
#   ('incezt.com', 'íŉcez4.com', 1.0),
#   ('incezt.com', 'incēztgr.com', 1.0),
#   ('wbsrch.com', 'wbsrchl.com', 1.0),
#   ('wbsrch.com', 'wwbsrchs.com', 1.0),
#   ('wbsrch.com', 'w_wbsrsh.com', 1.0),
#   ('wbsrch.com', 'wbsřȑch.com', 1.0),
#   ('wbsrch.com', 'wbśrçh.com', 1.0),
#   ('wbsrch.com', 'ẁƀsrċh.com', 1.0),
#   ('wbsrch.com', 'wƀs-rch.com', 1.0),
#   ('wbsrch.com', 'wśrçh.com', 1.0),
#   ('wbsrch.com', 'wẉbsrchv.com', 1.0),
#   ('heartsofpets.com', 'heartsofepts.com', 1.0),
#   ('heartsofpets.com', 'heartsolpets.com', 1.0),
#   ('heartsofpets.com', 'heartsndpets.com', 1.0),
#   ('heartsofpets.com', 'heartsoƒpets.com', 1.0),
#   ('heartsofpets.com', 'hearțsoſpets.com', 1.0),
#   ('heartsofpets.com', 'hearțsofpėťs.com', 1.0),
#   ('heartsofpets.com', 'lhèartsofpets.com', 1.0),
#   ('heartsofpets.com', 'heaŗusofƥets.com', 1.0),
#   ('heartsofpets.com', 'hearusŏdpets.com', 1.0),
#   ('vrbrothers.com', 'vrbrothersf.com', 1.0),
#   ('vrbrothers.com', 'vrlbrot-hers.com', 1.0),
#   ('vrbrothers.com', 'vrlbroothersa.com', 1.0),
#   ('vrbrothers.com', 'ṿrbrothers.com', 1.0),
#   ('vrbrothers.com', 'vrƀrõthers.com', 1.0),
#   ('vrbrothers.com', 'vrbroţheřȑś.com', 1.0),
#   ('vrbrothers.com', 'vrbřȑothersu.com', 1.0),
#   ('vrbrothers.com', 'ṽȓbrothmrs.com', 1.0),
#   ('vrbrothers.com', 'vrlb-ŗothers.com', 1.0),
#   ('mypaga.com', 'mypawa.com', 1.0),
#   ('mypaga.com', 'eyp4ga.com', 1.0),
#   ('mypaga.com', 'eyp_agad.com', 1.0),
#   ('mypaga.com', 'mýpaga.com', 1.0),
#   ('mypaga.com', 'ɱyƥaga.com', 1.0),
#   ('mypaga.com', 'mẏpágă.com', 1.0),
#   ('mypaga.com', 'mypaģ.com', 1.0),
#   ('mypaga.com', 'myƥa6a.com', 1.0),
#   ('mypaga.com', 'eypaģ_a.com', 1.0),
#   ('dnfziliao.com', 'dnfzimiao.com', 1.0),
#   ('dnfziliao.com', 'dnfi-liao.com', 1.0),
#   ('dnfziliao.com', 'dnnfiliaof.com', 1.0),
#   ('dnfziliao.com', 'dńfziliao.com', 1.0),
#   ('dnfziliao.com', 'dnfziĺíao.com', 1.0),
#   ('dnfziliao.com', 'dŋſziliāo.com', 1.0),
#   ('dnfziliao.com', 'dnfzziľiao.com', 1.0),
#   ('dnfziliao.com', 'tnfzįlíao.com', 1.0),
#   ('dnfziliao.com', 'dnfiĺiaor.com', 1.0),
#   ('alankabout.com', 'alankabou7.com', 1.0),
#   ('alankabout.com', 'alankab0utz.com', 1.0),
#   ('alankabout.com', 'anankaboupz.com', 1.0),
#   ('alankabout.com', 'älankabout.com', 1.0),
#   ('alankabout.com', 'alaŉkabòut.com', 1.0),
#   ('alankabout.com', 'ałånkábout.com', 1.0),
#   ('alankabout.com', 'alânkaboutj.com', 1.0),
#   ('alankabout.com', 'alankƀouť.com', 1.0),
#   ('alankabout.com', 'alanķabotz.com', 1.0),
#   ('indiavoice.com', 'indiavoic_e.com', 1.0),
#   ('indiavoice.com', 'iod1avoice.com', 1.0),
#   ('indiavoice.com', 'ind0avoicu.com', 1.0),
#   ('indiavoice.com', 'iŉdiavoice.com', 1.0),
#   ('indiavoice.com', 'índiavoĩce.com', 1.0),
#   ('indiavoice.com', 'ińdiaṽoicè.com', 1.0),
#   ('indiavoice.com', 'i_ndiävoice.com', 1.0),
#   ('indiavoice.com', 'índiavoičen.com', 1.0),
#   ('indiavoice.com', 'ind1avoiĉep.com', 1.0),
#   ('seopowersuite.com', 'seorowersuite.com', 1.0),
#   ('seopowersuite.com', 'seopow_resuite.com', 1.0),
#   ('seopowersuite.com', 'coepow_ersuite.com', 1.0),
#   ('seopowersuite.com', 'seopoŴersuite.com', 1.0),
#   ('seopowersuite.com', 'seopoẇersųite.com', 1.0),
#   ('seopowersuite.com', 'seoþøwersuíte.com', 1.0),
#   ('seopowersuite.com', 'sopowersµite.com', 1.0),
#   ('seopowersuite.com', 'seoƥoșersuite.com', 1.0),
#   ('seopowersuite.com', 'seopow_erʂtite.com', 1.0),
#   ('allnigerians.com', 'allnigeriansx.com', 1.0),
#   ('allnigerians.com', 'allniyer-ians.com', 1.0),
#   ('allnigerians.com', 'alljiger-lans.com', 1.0),
#   ('allnigerians.com', 'ałlnigerians.com', 1.0),
#   ('allnigerians.com', 'allnıgeřȑians.com', 1.0),
#   ('allnigerians.com', 'aŀlŋiģerians.com', 1.0),
#   ('allnigerians.com', 'allnigeɍhans.com', 1.0),
#   ('allnigerians.com', 'a_llnigėrïans.com', 1.0),
#   ('allnigerians.com', 'allhiger-ĭans.com', 1.0),
#   ('windows-commandline.com', 'windows-commandlineb.com', 1.0),
#   ...],
#  'train': [('okayplayer.com', 'okayplaiier.com', 1.0),
#   ('okayplayer.com', 'o-keyplayer.com', 1.0),
#   ('okayplayer.com', 'okayplayez.com', 1.0),
#   ('okayplayer.com', 'okayðlayer.com', 1.0),
#   ('okayplayer.com', 'okayplàyeřȑ.com', 1.0),
#   ('okayplayer.com', 'õkaÿðlayer.com', 1.0),
#   ('okayplayer.com', 'ojayƥlayer.com', 1.0),
#   ('okayplayer.com', 'okaýðlayer.com', 1.0),
#   ('okayplayer.com', 'okeypplaŷer.com', 1.0),
#   ('ecobolsa.com', 'ecobolsas.com', 1.0),
#   ('ecobolsa.com', 'ecobollsah.com', 1.0),
#   ('ecobolsa.com', 'ecoboll_si.com', 1.0),
#   ('ecobolsa.com', 'ecøbolsa.com', 1.0),
#   ('ecobolsa.com', 'ecøbolsä.com', 1.0),
#   ('ecobolsa.com', 'ecoƀolŝá.com', 1.0),
#   ('ecobolsa.com', 'ecobolșan.com', 1.0),
#   ('ecobolsa.com', 'ecoƀōl5a.com', 1.0),
#   ('ecobolsa.com', 'ečobolsla.com', 1.0),
#   ('listal.com', 'listalb.com', 1.0),
#   ('listal.com', 'lis4l.com', 1.0),
#   ('listal.com', 'listl_f.com', 1.0),
#   ('listal.com', 'listał.com', 1.0),
#   ('listal.com', 'ĺıstal.com', 1.0),
#   ('listal.com', 'ļisŧaļ.com', 1.0),
#   ('listal.com', 'lmʂtal.com', 1.0),
#   ('listal.com', 'liş7al.com', 1.0),
#   ('listal.com', 'ilsʈl.com', 1.0),
#   ('webdirectory.com', 'webirectory.com', 1.0),
#   ('webdirectory.com', 'webdhrectopy.com', 1.0),
#   ('webdirectory.com', 'vebdirmctopy.com', 1.0),
#   ('webdirectory.com', 'webdirēctory.com', 1.0),
#   ('webdirectory.com', 'webƌirectõry.com', 1.0),
#   ('webdirectory.com', 'webďiręctořȑy.com', 1.0),
#   ('webdirectory.com', 'webďirec_tory.com', 1.0),
#   ('webdirectory.com', 'webtírectóry.com', 1.0),
#   ('webdirectory.com', 'webƋirectopyo.com', 1.0),
#   ('geteasysolution.com', 'g-eteasysolution.com', 1.0),
#   ('geteasysolution.com', 'geteasysolutkin.com', 1.0),
#   ('geteasysolution.com', 'geteasyysolutokn.com', 1.0),
#   ('geteasysolution.com', 'geteasysolutïon.com', 1.0),
#   ('geteasysolution.com', 'geteasẏsoļution.com', 1.0),
#   ('geteasysolution.com', 'gęteasysoluťioñ.com', 1.0),
#   ('geteasysolution.com', 'ģeteasysolutino.com', 1.0),
#   ('geteasysolution.com', 'geteasysōluʈon.com', 1.0),
#   ('geteasysolution.com', 'geteašysolu4oin.com', 1.0),
#   ('chem4kids.com', 'chem4jids.com', 1.0),
#   ('chem4kids.com', 'chemk4ils.com', 1.0),
#   ('chem4kids.com', 'cheakils.com', 1.0),
#   ('chem4kids.com', 'chem4ķids.com', 1.0),
#   ('chem4kids.com', 'chem4kiďʂ.com', 1.0),
#   ('chem4kids.com', 'chêm4ķidș.com', 1.0),
#   ('chem4kids.com', 'chem4kies.com', 1.0),
#   ('chem4kids.com', 'ćhem4ķidss.com', 1.0),
#   ('chem4kids.com', 'chem4ķilsm.com', 1.0),
#   ('2chmatome2.com', '2chmatome2b.com', 1.0),
#   ('2chmatome2.com', '2chmato-e.com', 1.0),
#   ('2chmatome2.com', '2chmtoee.com', 1.0),
#   ('2chmatome2.com', '2chmațome2.com', 1.0),
#   ('2chmatome2.com', '2ćhmatöme2.com', 1.0),
#   ('2chmatome2.com', '2cħɱatome2.com', 1.0),
#   ('2chmatome2.com', '2chmatonē2.com', 1.0),
#   ('2chmatome2.com', '2chmãtomé_2.com', 1.0),
#   ('2chmatome2.com', '2chmaťomeq.com', 1.0),
#   ('thegraciouspantry.com', 'thegraciouspantrq.com', 1.0),
#   ('thegraciouspantry.com', 'thegrcciouspentry.com', 1.0),
#   ('thegraciouspantry.com', 'thefrccious0antry.com', 1.0),
#   ('thegraciouspantry.com', 'thegraciousðantry.com', 1.0),
#   ('thegraciouspantry.com', 'thegraciousƥaŋtry.com', 1.0),
#   ('thegraciouspantry.com', 'thęgraçiouspantrÿ.com', 1.0),
#   ('thegraciouspantry.com', 'thegrasiouspanťry.com', 1.0),
#   ('thegraciouspantry.com', 'thegraaciouspãntɍy.com', 1.0),
# ...
#   ('hideoxy.com', 'hideozy.com', 1.0),
#   ('hideoxy.com', '4idexoy.com', 1.0),
#   ('hideoxy.com', 'hitdxoy.com', 1.0),
#   ('hideoxy.com', 'hiděoxy.com', 1.0),
#   ('hideoxy.com', 'hidēoẍy.com', 1.0),
#   ('hideoxy.com', 'ħiđeŏxy.com', 1.0),
#   ('hideoxy.com', 'hideo8ẏ.com', 1.0),
#   ('hideoxy.com', 'ħibeoẍy.com', 1.0),
#   ('hideoxy.com', 'hĭdexoys.com', 1.0),
#   ('alltrails.com', 'alltrailsb.com', 1.0),
#   ('alltrails.com', 'ylltrails.com', 1.0),
#   ('alltrails.com', 'qllt_railsh.com', 1.0),
#   ('alltrails.com', 'alļtrails.com', 1.0),
#   ('alltrails.com', 'alľtrailš.com', 1.0),
#   ('alltrails.com', 'alltŗãĩls.com', 1.0),
#   ('alltrails.com', 'ālltra_ils.com', 1.0),
#   ('alltrails.com', 'altɍaiľs.com', 1.0),
#   ('alltrails.com', 'qlłtrailsy.com', 1.0),
#   ('supercook.com', 'spuercook.com', 1.0),
#   ('supercook.com', 'rupercook_.com', 1.0),
#   ('supercook.com', 'ruueprcook.com', 1.0),
#   ('supercook.com', 'suðercook.com', 1.0),
#   ('supercook.com', 'śuðercook.com', 1.0),
#   ('supercook.com', 'ŝûperĉook.com', 1.0),
#   ('supercook.com', 'sup-ercooķ.com', 1.0),
#   ('supercook.com', 'sūrercooķ.com', 1.0),
#   ('supercook.com', 'rupêrcooik.com', 1.0),
#   ('shinee.com', 'shin_ee.com', 1.0),
#   ('shinee.com', 'shnieek.com', 1.0),
#   ('shinee.com', 'sjnieey.com', 1.0),
#   ('shinee.com', 'shinęe.com', 1.0),
#   ('shinee.com', 'sħineė.com', 1.0),
#   ('shinee.com', 'šħineě.com', 1.0),
#   ('shinee.com', 'ʂhinme.com', 1.0),
#   ('shinee.com', 'šhiņeeo.com', 1.0),
#   ('shinee.com', 'șhnieeg.com', 1.0),
#   ('budgetbytes.com', 'budgetbytess.com', 1.0),
#   ('budgetbytes.com', 'budgetbyveq.com', 1.0),
#   ('budgetbytes.com', 'b5dgedbyves.com', 1.0),
#   ('budgetbytes.com', 'budgețbytes.com', 1.0),
#   ('budgetbytes.com', 'bȕdgeʈbytes.com', 1.0),
#   ('budgetbytes.com', 'bùďgeťbytes.com', 1.0),
#   ('budgetbytes.com', 'ƀudgetbytds.com', 1.0),
#   ('budgetbytes.com', 'budgeťbŷtesj.com', 1.0),
#   ('budgetbytes.com', 'budgetbyṽms.com', 1.0),
#   ('pricefalls.com', 'pricefanls.com', 1.0),
#   ('pricefalls.com', 'pricafal1s.com', 1.0),
#   ('pricefalls.com', 'pricetcl1s.com', 1.0),
#   ('pricefalls.com', 'priceƒalls.com', 1.0),
#   ('pricefalls.com', 'pricēfalŀs.com', 1.0),
#   ('pricefalls.com', 'pricèfäľls.com', 1.0),
#   ('pricefalls.com', 'ɋricefalls.com', 1.0),
#   ('pricefalls.com', 'prċiefálls.com', 1.0),
#   ('pricefalls.com', 'pric-ęfal1s.com', 1.0),
#   ('le-site-de.com', 'le-sitee-de.com', 1.0),
#   ('le-site-de.com', 'oe-site-de.com', 1.0),
#   ('le-site-de.com', 'nu-site-e.com', 1.0),
#   ('le-site-de.com', 'ľe-site-de.com', 1.0),
#   ('le-site-de.com', 'le-sítě-de.com', 1.0),
#   ('le-site-de.com', 'ĺe-siʈe-Ƌe.com', 1.0),
#   ('le-site-de.com', 'lę-siite-de.com', 1.0),
#   ('le-site-de.com', 'lë-šite-dey.com', 1.0),
#   ('le-site-de.com', 'ne-site-del.com', 1.0),
#   ('vectordiary.com', 'vectordiar_y.com', 1.0),
#   ('vectordiary.com', 'v_ectordary.com', 1.0),
#   ('vectordiary.com', 'v_ector_dlary.com', 1.0),
#   ('vectordiary.com', 'vectordìary.com', 1.0),
#   ('vectordiary.com', 'vecțoŗdiary.com', 1.0),
#   ('vectordiary.com', 'vecťordiaŕÿ.com', 1.0),
#   ('vectordiary.com', 'vectordìaryw.com', 1.0),
#   ('vectordiary.com', 'veĉtord-iaŗy.com', 1.0),
#   ('vectordiary.com', 'v_ectordiray.com', 1.0),
#   ('avaro.com', 'avaroc.com', 1.0),
#   ('avaro.com', 'afarol.com', 1.0),
#   ('avaro.com', 'afaorx.com', 1.0),
#   ('avaro.com', 'aṿaro.com', 1.0),
#   ('avaro.com', 'aṽarŏ.com', 1.0),
#   ('avaro.com', 'avāɍø.com', 1.0),
#   ('avaro.com', 'a-ṿaro.com', 1.0),
#   ('avaro.com', 'âṽaroz.com', 1.0),
#   ('avaro.com', 'åfazo.com', 1.0),
#   ('9miao.com', '9mico.com', 1.0),
#   ('9miao.com', '9aio.com', 1.0),
#   ('9miao.com', 'mcio.com', 1.0),
#   ('9miao.com', '9ɱiao.com', 1.0),
#   ('9miao.com', '9ɱiaø.com', 1.0),
#   ('9miao.com', '9ɱįaõ.com', 1.0),
#   ('9miao.com', 'gmiäo.com', 1.0),
#   ('9miao.com', '9ɱiö.com', 1.0),
#   ('9miao.com', '9ɱeio.com', 1.0),
#   ('naydidom.com', 'naaydidom.com', 1.0),
#   ('naydidom.com', 'naydidmd.com', 1.0),
#   ('naydidom.com', 'naydidomdic.com', 1.0),
#   ('naydidom.com', 'nayƌidom.com', 1.0),
#   ('naydidom.com', 'ŋaydiďom.com', 1.0),
#   ('naydidom.com', 'ńaÿđidom.com', 1.0),
#   ('naydidom.com', 'nay_dìdom.com', 1.0),
#   ('naydidom.com', 'naydĥdôm.com', 1.0),
#   ('naydidom.com', 'măydidomd.com', 1.0),
#   ('ford4arab.com', 'ford4arabo.com', 1.0),
#   ('ford4arab.com', 'bord4arabb.com', 1.0),
#   ('ford4arab.com', 'bord4arafo.com', 1.0),
#   ('ford4arab.com', 'ford4araƀ.com', 1.0),
#   ('ford4arab.com', 'førd4araƀ.com', 1.0),
#   ('ford4arab.com', 'ford4aŗaƀ.com', 1.0),
#   ('ford4arab.com', 'ford4qrab.com', 1.0),
#   ('ford4arab.com', 'vord4ąŗab.com', 1.0),
#   ('ford4arab.com', 'bord4ara8.com', 1.0),
#   ('redditenhancementsuite.com', 'vedditenhancementsuite.com', 1.0),
#   ('redditenhancementsuite.com', 'redditenahfcementsuite.com', 1.0),
#   ('redditenhancementsuite.com', 'redditenhafcemenu-suite.com', 1.0),
#   ('redditenhancementsuite.com', 'redditenhancementsµite.com', 1.0),
#   ('redditenhancementsuite.com', 'řȑedditenhancementsuîte.com', 1.0),
#   ('redditenhancementsuite.com', 'redditeŋhancementșȕite.com', 1.0),
#   ('redditenhancementsuite.com', 're_dditenhancementsȕite.com', 1.0),
#   ('redditenhancementsuite.com', 'redditeŉnhanceɱentsuite.com', 1.0),
#   ('redditenhancementsuite.com', 'ređditenhafcememtsuite.com', 1.0),
#   ('wookmark.com', 'woolkmark.com', 1.0),
#   ('wookmark.com', 'wookamrks.com', 1.0),
#   ('wookmark.com', 'wookahrk.com', 1.0),
#   ('wookmark.com', 'wookmarķ.com', 1.0),
#   ('wookmark.com', 'ẇooķmark.com', 1.0),
#   ('wookmark.com', 'ẇookɱârk.com', 1.0),
#   ('wookmark.com', 'wookmařȑke.com', 1.0),
#   ('wookmark.com', 'sookmãɍk.com', 1.0),
#   ('wookmark.com', 'Ŵooka-rk.com', 1.0),
#   ('tm085.com', 'tm085e.com', 1.0),
#   ('tm085.com', 'tmp85u.com', 1.0),
#   ('tm085.com', 'tm085uhe.com', 1.0),
#   ('tm085.com', 'ţm085.com', 1.0),
#   ('tm085.com', 'ţm085.com', 1.0),
#   ('tm085.com', 'țɱ085.com', 1.0),
#   ('tm085.com', 'tm085m.com', 1.0),
#   ('tm085.com', 'ŧnn085.com', 1.0),
#   ('tm085.com', 'ʈl085u.com', 1.0),
#   ('2kandy.com', '2kand-y.com', 1.0),
#   ('2kandy.com', '2kkan-dy.com', 1.0),
#   ('2kandy.com', '2kar-dyb.com', 1.0),
#   ('2kandy.com', '2kandý.com', 1.0),
#   ('2kandy.com', '2kąŉdy.com', 1.0),
#   ('2kandy.com', '2káńdŷ.com', 1.0),
#   ('2kandy.com', '2kaņty.com', 1.0),
#   ('2kandy.com', '2canƌẏ.com', 1.0),
#   ('2kandy.com', '3kąn-dy.com', 1.0),
#   ('hermitagemuseum.com', 'hermitagemusgum.com', 1.0),
#   ('hermitagemuseum.com', 'hermhtagemus_eum.com', 1.0),
#   ('hermitagemuseum.com', 'hermitagelus_eumo.com', 1.0),
#   ('hermitagemuseum.com', 'hermitãgemuseum.com', 1.0),
#   ('hermitagemuseum.com', 'heřȑmitagemuseuɱ.com', 1.0),
#   ('hermitagemuseum.com', 'ħermiŧagemȕseum.com', 1.0),
#   ('hermitagemuseum.com', 'heɍmitagemuseumv.com', 1.0),
#   ('hermitagemuseum.com', 'ħesmitagemušeum.com', 1.0),
#   ('hermitagemuseum.com', 'hermitagemu_s_eum.com', 1.0),
#   ('ucweb.com', 'ucwebm.com', 1.0),
#   ('ucweb.com', 'cweb.com', 1.0),
#   ('ucweb.com', 'tcwebu.com', 1.0),
#   ('ucweb.com', 'ucwėb.com', 1.0),
#   ('ucweb.com', 'uĉweƀ.com', 1.0),
#   ('ucweb.com', 'ůčweƀ.com', 1.0),
#   ('ucweb.com', 'tćweb.com', 1.0),
#   ('ucweb.com', 'ucweƀá.com', 1.0),
#   ('ucweb.com', 'țcwebi.com', 1.0),
#   ('mohrss.com', 'nnohrss.com', 1.0),
#   ('mohrss.com', 'mo_hrssz.com', 1.0),
#   ('mohrss.com', 'mohrss-zb.com', 1.0),
#   ('mohrss.com', 'mohȓss.com', 1.0),
#   ('mohrss.com', 'ɱoĥrss.com', 1.0),
#   ('mohrss.com', 'ɱòħrss.com', 1.0),
#   ('mohrss.com', 'mohrşsi.com', 1.0),
#   ('mohrss.com', 'moĥrsŝw.com', 1.0),
#   ('mohrss.com', 'mohssż.com', 1.0),
#   ('investfourmore.com', 'inv-estfourmore.com', 1.0),
#   ('investfourmore.com', 'investfourmnrex.com', 1.0),
#   ('investfourmore.com', 'investfourmjreh.com', 1.0),
#   ('investfourmore.com', 'inveștfourmore.com', 1.0),
#   ('investfourmore.com', 'investƒourɱore.com', 1.0),
#   ('investfourmore.com', 'inveʂtfourɱoŕe.com', 1.0),
#   ('investfourmore.com', 'lnveŝtfourmore.com', 1.0),
#   ('investfourmore.com', 'investfoẅrmōre.com', 1.0),
#   ('investfourmore.com', 'investƒourmne.com', 1.0),
#   ('westfield.com', 'westfi-eld.com', 1.0),
#   ('westfield.com', 'westviield.com', 1.0),
#   ('westfield.com', 'westvieldik.com', 1.0),
#   ('westfield.com', 'westfîeld.com', 1.0),
#   ('westfield.com', 'weʂtƒield.com', 1.0),
#   ('westfield.com', 'wësťfîeld.com', 1.0),
#   ('westfield.com', 'westfiĕlcl.com', 1.0),
#   ('westfield.com', 'weśtielđ.com', 1.0),
#   ('westfield.com', 'weștviell.com', 1.0),
#   ('brokers-science.com', 'brmkers-science.com', 1.0),
#   ('brokers-science.com', 'bsoiers-science.com', 1.0),
#   ('brokers-science.com', 'bsokers-scemnce.com', 1.0),
#   ('brokers-science.com', 'brokěrs-science.com', 1.0),
#   ('brokers-science.com', 'bȓokěrs-science.com', 1.0),
#   ('brokers-science.com', 'broķěrs-scieŋce.com', 1.0),
#   ('brokers-science.com', 'brokërs-sciece.com', 1.0),
#   ('brokers-science.com', 'broers-șcienĉe.com', 1.0),
#   ('brokers-science.com', 'bsokers-scýence.com', 1.0),
#   ('sinonimus.com', 'sino-nimus.com', 1.0),
#   ('sinonimus.com', 'sinonimus.com', 1.0),
#   ('sinonimus.com', 'sinonimus_bo.com', 1.0),
#   ('sinonimus.com', 'sĭnonimus.com', 1.0),
#   ('sinonimus.com', 'sínoŉimus.com', 1.0),
#   ('sinonimus.com', 'śinonįmůs.com', 1.0),
#   ('sinonimus.com', 'sionniɱus.com', 1.0),
#   ('sinonimus.com', 'siooniɱµs.com', 1.0),
#   ('sinonimus.com', 'sinŏnmmusb.com', 1.0),
#   ('omron.com', 'om_ron.com', 1.0),
#   ('omron.com', 'mgron.com', 1.0),
#   ('omron.com', 'gmrrono.com', 1.0),
#   ('omron.com', 'oɱron.com', 1.0),
#   ('omron.com', 'omrŏŉ.com', 1.0),
#   ('omron.com', 'ōmɍoñ.com', 1.0),
#   ('omron.com', 'orřȑron.com', 1.0),
#   ('omron.com', 'oɱɍno.com', 1.0),
#   ('omron.com', '_gmron.com', 1.0),
#   ('gosavo.com', 'gosivo.com', 1.0),
#   ('gosavo.com', 'o-gsavo.com', 1.0),
#   ('gosavo.com', 'og-savou.com', 1.0),
#   ('gosavo.com', 'goŝavo.com', 1.0),
#   ('gosavo.com', 'gōşavo.com', 1.0),
#   ('gosavo.com', 'ġòʂavo.com', 1.0),
#   ('gosavo.com', 'oșavo.com', 1.0),
#   ('gosavo.com', 'ģos4ṿo.com', 1.0),
#   ('gosavo.com', 'ogsã-vo.com', 1.0),
#   ('lambsteps.com', 'lambstep3.com', 1.0),
#   ('lambsteps.com', 'lam8stes.com', 1.0),
#   ('lambsteps.com', 'lam8stepskm.com', 1.0),
#   ('lambsteps.com', 'lamƀsteps.com', 1.0),
#   ('lambsteps.com', 'laɱbstepş.com', 1.0),
#   ('lambsteps.com', 'lâɱbstepʂ.com', 1.0),
#   ('lambsteps.com', 'lambstëpps.com', 1.0),
#   ('lambsteps.com', 'łambsțepsl.com', 1.0),
#   ('lambsteps.com', 'lam8ćteps.com', 1.0),
#   ('shopmissa.com', 'shopmsisa.com', 1.0),
#   ('shopmissa.com', 'shopmisscu.com', 1.0),
#   ('shopmissa.com', 'shopmmqsc.com', 1.0),
#   ('shopmissa.com', 'shopɱissa.com', 1.0),
#   ('shopmissa.com', 'shōpmíssa.com', 1.0),
#   ('shopmissa.com', 'şhòþmissa.com', 1.0),
#   ('shopmissa.com', 'shopëissa.com', 1.0),
#   ('shopmissa.com', 'șhopnńissa.com', 1.0),
#   ('shopmissa.com', 'shopmisścz.com', 1.0),
#   ('libaclub.com', 'libaclubx.com', 1.0),
#   ('libaclub.com', 'imbaclub.com', 1.0),
#   ('libaclub.com', 'lmbachqb.com', 1.0),
#   ('libaclub.com', 'ľibaclub.com', 1.0),
#   ('libaclub.com', 'libąćlub.com', 1.0),
#   ('libaclub.com', 'lįbācļub.com', 1.0),
#   ('libaclub.com', 'libaƀlub.com', 1.0),
#   ('libaclub.com', 'lłiƀaclub.com', 1.0),
#   ('libaclub.com', 'lmbaclµr.com', 1.0),
#   ('tahribat.com', 'tah2ibat.com', 1.0),
#   ('tahribat.com', 'tahricatz.com', 1.0),
#   ('tahribat.com', 'tahricate.com', 1.0),
#   ('tahribat.com', 'tahȓibat.com', 1.0),
#   ('tahribat.com', 'taĥribať.com', 1.0),
#   ('tahribat.com', 'ţaħribąt.com', 1.0),
#   ('tahribat.com', 'tqhribāt.com', 1.0),
#   ('tahribat.com', 'ŧa_hriƀat.com', 1.0),
#   ('tahribat.com', 'taħricatg.com', 1.0),
#   ('expatriates.com', 'expatrites.com', 1.0),
#   ('expatriates.com', 'expatiratesr.com', 1.0),
#   ('expatriates.com', 'exr4tirates.com', 1.0),
#   ('expatriates.com', 'exƥatriates.com', 1.0),
#   ('expatriates.com', 'expatrìatĕs.com', 1.0),
#   ('expatriates.com', 'exðatrìateş.com', 1.0),
#   ('expatriates.com', 'exxpatriateș.com', 1.0),
#   ('expatriates.com', 'éxpâtrites.com', 1.0),
#   ('expatriates.com', 'expatiŕater.com', 1.0),
#   ('online-life.com', 'onli_ne-life.com', 1.0),
#   ('online-life.com', 'onlira-life.com', 1.0),
#   ('online-life.com', 'oniire-liife.com', 1.0),
#   ('online-life.com', 'ònline-life.com', 1.0),
#   ('online-life.com', 'onlinė-life.com', 1.0),
#   ('online-life.com', 'ònlìnė-life.com', 1.0),
#   ('online-life.com', 'onli_ně-life.com', 1.0),
#   ('online-life.com', 'online-lińè.com', 1.0),
#   ('online-life.com', 'ollire-lifë.com', 1.0),
#   ('bizchen.com', 'cizchen.com', 1.0),
#   ('bizchen.com', 'bizcihenc.com', 1.0),
#   ('bizchen.com', 'bicziheni.com', 1.0),
#   ('bizchen.com', 'bizcħen.com', 1.0),
#   ('bizchen.com', 'bïźchen.com', 1.0),
#   ('bizchen.com', 'bizçħeņ.com', 1.0),
#   ('bizchen.com', 'ĭbzchen.com', 1.0),
#   ('bizchen.com', 'bizč_heņ.com', 1.0),
#   ('bizchen.com', 'biẓcihen.com', 1.0),
#   ('chodan.com', 'chodanq.com', 1.0),
#   ('chodan.com', 'ch-odang.com', 1.0),
#   ('chodan.com', 'c_h-odcn.com', 1.0),
#   ('chodan.com', 'chodân.com', 1.0),
#   ('chodan.com', 'ĉhodaŉ.com', 1.0),
#   ('chodan.com', 'choƌåň.com', 1.0),
#   ('chodan.com', 'chodąnb.com', 1.0),
#   ('chodan.com', 'cħòdanr.com', 1.0),
#   ('chodan.com', 'ch-mdán.com', 1.0),
#   ('almundo.com', 'almunto.com', 1.0),
#   ('almundo.com', 'alrnundoz.com', 1.0),
#   ('almundo.com', 'clmujdoz.com', 1.0),
#   ('almundo.com', 'almunđo.com', 1.0),
#   ('almundo.com', 'aŀɱundo.com', 1.0),
#   ('almundo.com', 'aľmµnƋo.com', 1.0),
#   ('almundo.com', 'clɱundo.com', 1.0),
#   ('almundo.com', 'amũñdo.com', 1.0),
#   ('almundo.com', 'almunţoz.com', 1.0),
#   ('zevka.com', '2evka.com', 1.0),
#   ('zevka.com', 'zzevkam.com', 1.0),
#   ('zevka.com', 'zdvka44.com', 1.0),
#   ('zevka.com', 'zęvka.com', 1.0),
#   ('zevka.com', 'zeṿķa.com', 1.0),
#   ('zevka.com', 'ẑeṿķa.com', 1.0),
#   ('zevka.com', 'ẓevia.com', 1.0),
#   ('zevka.com', 'żeṽkav.com', 1.0),
#   ('zevka.com', 'ze_vkam.com', 1.0),
#   ('worldfreeads.com', 'worldfreeabs.com', 1.0),
#   ('worldfreeads.com', 'worl_dfreeadso.com', 1.0),
#   ('worldfreeads.com', 'worldfreeatsot.com', 1.0),
#   ('worldfreeads.com', 'worldfreèads.com', 1.0),
#   ('worldfreeads.com', 'woȓldfreeãds.com', 1.0),
#   ('worldfreeads.com', 'worłdfŗeeadś.com', 1.0),
#   ('worldfreeads.com', 'worldfrdėads.com', 1.0),
#   ('worldfreeads.com', 'worlďrfeęads.com', 1.0),
#   ('worldfreeads.com', 'wnrļdfreeadso.com', 1.0),
#   ('lifeasmama.com', 'hifeasmama.com', 1.0),
#   ('lifeasmama.com', 'liifeasmam_a.com', 1.0),
#   ('lifeasmama.com', 'lifeasmam-_as.com', 1.0),
#   ('lifeasmama.com', 'lifeåsmama.com', 1.0),
#   ('lifeasmama.com', 'lifeäsmamą.com', 1.0),
#   ('lifeasmama.com', 'lïƒeasɱama.com', 1.0),
#   ('lifeasmama.com', 'lıfeaslama.com', 1.0),
#   ('lifeasmama.com', 'łivéasmama.com', 1.0),
#   ('lifeasmama.com', 'lifeamśam_a.com', 1.0),
#   ('verisign.com', 'veriign.com', 1.0),
#   ('verisign.com', 'veriisg_n.com', 1.0),
#   ('verisign.com', 'veriisgnzo.com', 1.0),
#   ('verisign.com', 'verīsign.com', 1.0),
#   ('verisign.com', 'vęrïsign.com', 1.0),
#   ('verisign.com', 'ṽerísìgn.com', 1.0),
#   ('verisign.com', 'ver_isiģn.com', 1.0),
#   ('verisign.com', 'veƀisiğn.com', 1.0),
#   ('verisign.com', 'ṽeriicgn.com', 1.0),
#   ('performgroup.com', 'perforigroup.com', 1.0),
#   ('performgroup.com', 'parformgroupt.com', 1.0),
#   ('performgroup.com', 'parfmrgroup.com', 1.0),
#   ('performgroup.com', 'performgroűp.com', 1.0),
#   ('performgroup.com', 'peŕforɱgroup.com', 1.0),
#   ('performgroup.com', 'ƥerƒormğroup.com', 1.0),
#   ('performgroup.com', 'peȓfmrmgroup.com', 1.0),
#   ('performgroup.com', 'ðerforrrgrouþ.com', 1.0),
#   ('performgroup.com', 'parformrőup.com', 1.0),
#   ('tamiljaffna.com', 'tamiljadfna.com', 1.0),
#   ('tamiljaffna.com', 'tamiljaffna.com', 1.0),
#   ('tamiljaffna.com', 'damiljatfa.com', 1.0),
#   ('tamiljaffna.com', 'tamiljafſna.com', 1.0),
#   ('tamiljaffna.com', 'tamiłĵaffna.com', 1.0),
#   ('tamiljaffna.com', 'tâmiljāſfna.com', 1.0),
#   ('tamiljaffna.com', 'tamkljaffňa.com', 1.0),
#   ('tamiljaffna.com', 'tamiŀjaffŉ4.com', 1.0),
#   ('tamiljaffna.com', 'tamiljatfnaĺ.com', 1.0),
#   ('18p2p.com', 'q8p2p.com', 1.0),
#   ('18p2p.com', '18pp2pp.com', 1.0),
#   ('18p2p.com', '1pp2pp.com', 1.0),
#   ('18p2p.com', '18p2p.com', 1.0),
#   ('18p2p.com', '18p2p.com', 1.0),
#   ('18p2p.com', '18p2p.com', 1.0),
#   ('18p2p.com', '18p2pf.com', 1.0),
#   ('18p2p.com', '8p2p.com', 1.0),
#   ('18p2p.com', '18pƥp2.com', 1.0),
#   ('whisper.com', 'wwhisper.com', 1.0),
#   ...]}

# %%
font = '/content/ARIAL.TTF'

# %%
def img(text, path):     
    img = Image.new('L', (150, 12))
    fnt = ImageFont.truetype(font, 10)
    d = ImageDraw.Draw(img)
    d.text((0, 0), text, font=fnt, fill = (255))
    #enhancer = ImageEnhance.Contrast(img)
    #im_output = enhancer.enhance(1.5)
    #transposed  = img.transpose(Image.ROTATE_90)
    img.save(path + text + '.png', 'PNG')

# %%
train = [dom[0] for dom in data['train']]
test = [dom[0] for dom in data['test']]
valid = [dom[0] for dom in data['validate']]

# %%
uniq_train = list(set(train))
uniq_test = list(set(test))
uniq_valid = list(set(valid))

# %%
print(len(uniq_train), len(uniq_test), len(uniq_valid))
# Out:
# 69723 18349 3670

# %%
with open("domains_train.txt", "wb") as fp:
    pickle.dump(uniq_train, fp)

with open("domains_test.txt", "wb") as fp:
    pickle.dump(uniq_test, fp)

with open("domains_valid.txt", "wb") as fp:
    pickle.dump(uniq_valid, fp)

# %%
with open("domains_train.txt", "rb") as fp:
    domains_train = pickle.load(fp)

# %%
with open("domains_test.txt", "rb") as fp:
    domains_test = pickle.load(fp)

# %%
with open("domains_valid.txt", "rb") as fp:
    domains_valid = pickle.load(fp)

# %%
domains_train
# Out:
# ['warandpeace.com',
#  'bradford.com',
#  'hz66.com',
#  'brokensilenze.com',
#  'kienyke.com',
#  'tickmill.com',
#  'multcloud.com',
#  'partner-s.com',
#  'housing.com',
#  'cinemirchi.com',
#  'reapermini.com',
#  'pornpapa.com',
#  'webconfs.com',
#  'taxactonline.com',
#  'ivisits.com',
#  'spaceweather.com',
#  'mtj.com',
#  'kinezo.com',
#  'howardforums.com',
#  'kurosawagakki.com',
#  'elcorreoweb.com',
#  'bbstoday.com',
#  'pr4-articles.com',
#  'shoppeet.com',
#  'cr.com',
#  'helpx.com',
#  'paidbooks.com',
#  'awsurveys.com',
#  'bluedart.com',
#  'pearsonitcertification.com',
#  'knowledgehubmedia.com',
#  'numbersusa.com',
#  'shipsage.com',
#  'chartpark.com',
#  'novapress.com',
#  'wanderu.com',
#  'softsurroundings.com',
#  'playmoviez.com',
#  'mngcow.com',
#  'todays1051.com',
#  'apple-geeks.com',
#  'puup.com',
#  'demis.com',
#  'pbcgov.com',
#  'cityhouse.com',
#  'tunecore.com',
#  'domainindex.com',
#  'mystilus.com',
#  'zalando.com',
#  'internetcom.com',
#  'postbank.com',
#  'spigotmc.com',
#  'hermanmiller.com',
#  'pssclub.com',
#  'pozvonim.com',
#  'lopesnet.com',
#  'clktrack.com',
#  'detekno.com',
#  'clubemarketingdigital.com',
#  'file.com',
#  'openfaves.com',
#  'gadgetninja.com',
#  '8dascvesa.com',
#  'myday.com',
#  'qqzhi.com',
#  'saatvesaat.com',
#  'vtu.com',
#  'khuisf.com',
#  'eluniverso.com',
#  'store2door.com',
#  'medialibrary.com',
#  'russvet.com',
#  'viptijian.com',
#  'eatoye.com',
#  'mhhe.com',
#  'hq-sex-tube.com',
#  'obasanjukujo.com',
#  'imodules.com',
#  'momon-ga.com',
#  'dailyverses.com',
#  'playstationlifestyle.com',
#  'wahed.com',
#  'look-in.com',
#  'mifarma.com',
#  'sandiegounified.com',
#  'meupatrocinio.com',
#  'canvasrider.com',
#  'haltaalam.com',
#  'selfgrowth.com',
#  'funnies.com',
#  'noizz.com',
#  'mgoblue.com',
#  'loorin.com',
#  'rozklad-pkp.com',
#  'sabc.com',
#  'stuffgate.com',
#  'trt15.com',
#  'mudderonline.com',
#  'stayonthehealthypath.com',
#  'lfp.com',
#  'winespectator.com',
#  'wakacje.com',
#  'nutaku.com',
#  'gameboomers.com',
#  'holidify.com',
#  'superanimes.com',
#  'blog-mougenda.com',
#  'discovertricks.com',
#  'myrelatives.com',
#  'free-article-spinner.com',
#  'yx007.com',
#  'sylvania.com',
#  'bmn.com',
#  'becker.com',
#  'liketodiscover.com',
#  '5hoom.com',
#  'libri.com',
#  'peoplesmart.com',
#  'minus.com',
#  'thedailyrofl.com',
#  'pages03.com',
#  'howbuy.com',
#  'ierek.com',
#  'ssfshop.com',
#  'novelashdgratis.com',
#  'homeoint.com',
#  'talkingdata.com',
#  'zacjohnson.com',
#  'business-gazeta.com',
#  'ndonline.com',
#  'aetna.com',
#  'trickyenough.com',
#  'huaxia.com',
#  'videozhub.com',
#  'sureserver.com',
#  'whodoyou.com',
#  'thelovelyplanet.com',
#  'qschou.com',
#  'flybox.com',
#  'misfile.com',
#  'appsbar.com',
#  'pestools.com',
#  'xpcha.com',
#  '86db.com',
#  'cregital.com',
#  'adsafrica.com',
#  'economie.com',
#  'elementy.com',
#  'alzheimers.com',
#  'digitaling.com',
#  'coolthings.com',
#  'm2j.com',
#  'takas.com',
#  'firemountaingems.com',
#  'asrebank.com',
#  'moneysavingmom.com',
#  'pcnet.com',
#  '528.com',
#  'friends-online.com',
#  'eerong.com',
#  'airastana.com',
#  'indiarush.com',
#  'hdwallpaperscool.com',
#  'net767.com',
#  'bancolafise.com',
#  'uc56.com',
#  'e-mansion.com',
#  'freetetris.com',
#  'traffictravis.com',
#  'mybsn.com',
#  'interior.com',
#  'naxos.com',
#  'dziennikpolski24.com',
#  'apsense.com',
#  'humanproofdesigns.com',
#  'for-me-online.com',
#  'tranceone.com',
#  'taoke.com',
#  'scorpioncave.com',
#  'dhd24.com',
#  'nakaprin.com',
#  'veaha.com',
#  'helpticle.com',
#  'safeco.com',
#  'quiz-fun.com',
#  'o2.com',
#  'kaidee.com',
#  'humaniplex.com',
#  'empoweringparents.com',
#  'brighamandwomens.com',
#  'gujaratsamachar.com',
#  'online-go.com',
#  'fgl.com',
#  'dobraprace.com',
#  'sexpulse.com',
#  'projects.com',
#  'qxwar.com',
#  'lukou.com',
#  'sixpackshortcuts.com',
#  'teen.com',
#  'ulster.com',
#  'teepr.com',
#  'jaysalvat.com',
#  'uploadvr.com',
#  'apkbus.com',
#  'dq10ragu.com',
#  'grammy.com',
#  'ngmodules.com',
#  'hdchd.com',
#  'moreofit.com',
#  'bourdela.com',
#  'aqovd.com',
#  'khabarduni.com',
#  'tug.com',
#  'bethel.com',
#  'mp3suara.com',
#  'iambaker.com',
#  'quattroruote.com',
#  'aircel.com',
#  'thepiratebeach.com',
#  'emailmanager.com',
#  'ityran.com',
#  'weblink.com',
#  'n4bb.com',
#  'ofix.com',
#  'yi71.com',
#  'pg.com',
#  'dressilyme.com',
#  'bleachmx.com',
#  'mycatamaranrx.com',
#  'yaelp.com',
#  'vbird.com',
#  'wisebread.com',
#  'wowzee.com',
#  'sinemalar.com',
#  'qumaiya.com',
#  'harvard.com',
#  'first-jp.com',
#  'dottoro.com',
#  'saism.com',
#  'videogamer.com',
#  'wosign.com',
#  'quizz.com',
#  'artmusictrees.com',
#  'cleaneatingmag.com',
#  'oricon.com',
#  'mybobs.com',
#  'undiz.com',
#  'radaroficial.com',
#  'ceskatelevize.com',
#  'xuk.com',
#  'wcnc.com',
#  'telemagazyn.com',
#  'buzzsport.com',
#  'heao.com',
#  'costcotravel.com',
#  'gapyear.com',
#  'idkmen.com',
#  'utiket.com',
#  'apartmentlist.com',
#  'smofast.com',
#  'yelloyello.com',
#  'umk.com',
#  'thanhlapctyviet.com',
#  'e-coop.com',
#  '4ucharge.com',
#  'mlsfinder.com',
#  'audiorok.com',
#  'alkutubcafe.com',
#  'escapadarural.com',
#  'allied-id.com',
#  'synonimy.com',
#  'telkom.com',
#  'nijibondo.com',
#  'platekompaniet.com',
#  'holidayinsights.com',
#  'mashhad.com',
#  'webhosting.com',
#  'chinasspp.com',
#  'pcbchinanet.com',
#  'donotracker.com',
#  'ereyon.com',
#  'boostholdings.com',
#  'yabadu.com',
#  'raymourflanigan.com',
#  'showtime.com',
#  'gashplus.com',
#  '1nimo.com',
#  'momsbangteens.com',
#  'nbcmiami.com',
#  'dir001.com',
#  'lensculture.com',
#  'avsdown.com',
#  'esa.com',
#  'thetruetraveler.com',
#  'faysbook.com',
#  'themenatech.com',
#  'asiancorrespondent.com',
#  'sportal.com',
#  'changedetection.com',
#  'bing.com',
#  'bonoboplanet.com',
#  'clockworkmod.com',
#  'valutakurser.com',
#  'todo-mail.com',
#  'jumpshare.com',
#  'taxcare.com',
#  'uv.com',
#  'frontpad.com',
#  'bsh-partner.com',
#  'theultralinx.com',
#  'arabmatchmaking.com',
#  'rajamobil.com',
#  'pornoteria.com',
#  'upworthy.com',
#  'roche.com',
#  'babady.com',
#  'manageprojects.com',
#  'jiayuan.com',
#  'idahostatesman.com',
#  'assembla.com',
#  'soriana.com',
#  'abcam.com',
#  'moswar.com',
#  'mifcom.com',
#  'pretendyoure.com',
#  'legalmatch.com',
#  'ticimax.com',
#  'medfusion.com',
#  'jqueryui.com',
#  'fitxo.com',
#  'hima-game.com',
#  'ease2ad.com',
#  '6505.com',
#  'bafree.com',
#  'romzj.com',
#  'nigeriacommunicationsweek.com',
#  'rockymountainatvmc.com',
#  'lemall.com',
#  'car2go.com',
#  'kage-design.com',
#  'littledebbie.com',
#  'canyouactually.com',
#  'sedo.com',
#  'ulugov.com',
#  'ksu.com',
#  'travelkhana.com',
#  'blackmagicdesign.com',
#  'yxlady.com',
#  'is.com',
#  'odpovedi.com',
#  'webadictos.com',
#  'conoha.com',
#  'poptm.com',
#  'the-best-apps.com',
#  'bluepillmen.com',
#  'packersnews.com',
#  'grserver.com',
#  'mundopositivo.com',
#  'bea.com',
#  'totalwar.com',
#  'simpatie.com',
#  'bsesdelhi.com',
#  'alraimedia.com',
#  'iliangcang.com',
#  'nrf.com',
#  'weborama.com',
#  'fdget.com',
#  'citeulike.com',
#  'eshia.com',
#  'twcable.com',
#  'onthemarket.com',
#  'travel-portals.com',
#  'ceskereality.com',
#  'therednews.com',
#  'prdaily.com',
#  'traveltips4u.com',
#  'veer.com',
#  'thetimingsystem.com',
#  'infoscoutinc.com',
#  'sibsoft.com',
#  'testbag.com',
#  'decompileandroid.com',
#  'tvcook.com',
#  'moscow-faq.com',
#  'helios.com',
#  'regulations.com',
#  'iejdne.com',
#  'iesa.com',
#  'ashiyane.com',
#  'spacenews.com',
#  'baidu6.com',
#  'transportstyrelsen.com',
#  'differencebetween.com',
#  'thyrocare.com',
#  'fotki.com',
#  'a3maqagency.com',
#  'mirrorz.com',
#  'studytonight.com',
#  'eepw.com',
#  'teleshopping.com',
#  'hamariweb.com',
#  'famicloud.com',
#  'mytotalconnectcomfort.com',
#  'kasidie.com',
#  'skipthedishes.com',
#  'aasp.com',
#  'intermatico.com',
#  'landmarkglobal.com',
#  'tvprofil.com',
#  'unicode-table.com',
#  'gpgway.com',
#  'lojapescaalternativa.com',
#  'lookerchina.com',
#  'wmprom.com',
#  'geek.com',
#  'freitasleiloesonline.com',
#  'biolifeplasma.com',
#  'videisimo.com',
#  'gw630.com',
#  'seobythesea.com',
#  'tn8.com',
#  'folosit.com',
#  'xdate.com',
#  'aftenbladet.com',
#  'accountingtools.com',
#  'univ-paris1.com',
#  'joycasino.com',
#  'uah.com',
#  'buzzmonclick.com',
#  'guosen.com',
#  'daoyoudao.com',
#  'amino.com',
#  'ket-noi.com',
#  'influitive.com',
#  'jeddl.com',
#  'youwatchfilm.com',
#  'groono.com',
#  'autowini.com',
#  'my180.com',
#  'tivivodo.com',
#  '6m.com',
#  'vemale.com',
#  'uky.com',
#  'minitokyo.com',
#  'laps4.com',
#  'setlinks.com',
#  'theladders.com',
#  'kabarmakkah.com',
#  'lottost.com',
#  'mofei.com',
#  'argos.com',
#  'thepeakworkperformancesummit.com',
#  'alsasianporn.com',
#  '2nyan.com',
#  'razerzone.com',
#  'industryhit.com',
#  'upticknewswire.com',
#  'diariodocentrodomundo.com',
#  'ehost.com',
#  'areamobile.com',
#  'ucourses.com',
#  'ucheba.com',
#  'cjone.com',
#  'mokavilag.com',
#  'savemypocket.com',
#  'runtamil.com',
#  'lsigraph.com',
#  'adinehbook.com',
#  'thescore.com',
#  'sex-doma.com',
#  'zg99.com',
#  'money-prog.com',
#  'waheaven.com',
#  'win8china.com',
#  'silukee.com',
#  'szhff.com',
#  'privatejobshub.com',
#  'faststore.com',
#  'mangasempai.com',
#  'japannetbank.com',
#  'viso.com',
#  'extrapetite.com',
#  'esharesinc.com',
#  'scuolabook.com',
#  'xzzp.com',
#  'instantfap.com',
#  'albousla.com',
#  'gerdoo.com',
#  'traicy.com',
#  'sgames.com',
#  'gardners.com',
#  'konachan.com',
#  'cao.com',
#  'ulc.com',
#  'lenovojp.com',
#  'bbb.com',
#  'otservlist.com',
#  'freex.com',
#  'wnwb.com',
#  'cra-arc.com',
#  'game-de.com',
#  'visiondirect.com',
#  'klm.com',
#  'ibotoolbox.com',
#  'szhrss.com',
#  'ameinfo.com',
#  'jetbrains.com',
#  'meteo60.com',
#  'hertzcarsales.com',
#  'expandedramblings.com',
#  'erepublik.com',
#  'news-medical.com',
#  'worxware.com',
#  'ms-ins.com',
#  'cfp-psc.com',
#  'sccnn.com',
#  'pes.com',
#  'uni-corvinus.com',
#  'zahra-media.com',
#  'solidworks.com',
#  'gzjjzd.com',
#  'uppervolta-3d.com',
#  'gotut.com',
#  'agroinform.com',
#  'creditoagricola.com',
#  'goqr.com',
#  'fodizi.com',
#  'woophoop.com',
#  'wset.com',
#  'keenerkitchen.com',
#  'mp3-pesni.com',
#  'dexmedia.com',
#  'kshowdramaonline.com',
#  'atajitos.com',
#  'setarebux.com',
#  'oppainorakuen.com',
#  'coinsky.com',
#  'meethk.com',
#  'suara.com',
#  'edcba.com',
#  'ericdress.com',
#  'storehippo.com',
#  'ruutu.com',
#  'wfrcdn.com',
#  'loseit.com',
#  'ucr.com',
#  '8yyls.com',
#  'stgeorge.com',
#  'madajara.com',
#  'dealsandsavings.com',
#  'blum.com',
#  'uinjkt.com',
#  'muhasebetr.com',
#  'nbme.com',
#  'heapanalytics.com',
#  'ocu.com',
#  'truemoney.com',
#  'indianrailways.com',
#  'gamestoon.com',
#  'gxbs.com',
#  'e-gov.com',
#  'gamcore.com',
#  '7mgame.com',
#  'stevehoffman.com',
#  'qread.com',
#  'cruise.com',
#  'admarula.com',
#  'samsungsetup.com',
#  'reductress.com',
#  'netgeek.com',
#  'funfancy.com',
#  'clipconverter.com',
#  'sports-sante.com',
#  'celtx.com',
#  'xn--nyqy26a13k.com',
#  'siemprenoticias.com',
#  'isbilgisi.com',
#  'testbericht.com',
#  'indonez.com',
#  'amrita.com',
#  'sparklit.com',
#  'wallpapereast.com',
#  'i.com',
#  'premier-league-lives.com',
#  'ewha.com',
#  'fhb.com',
#  'orient-news.com',
#  'ldsmag.com',
#  'livability.com',
#  'faithtap.com',
#  'uark.com',
#  'selbst.com',
#  'thehardtimes.com',
#  'elaph.com',
#  'accessmygov.com',
#  'medpex.com',
#  'meest.com',
#  'iea.com',
#  'search-one.com',
#  'add0n.com',
#  'antikvarium.com',
#  'travellerblog.com',
#  'mayo.com',
#  'mq.com',
#  'hometipsworld.com',
#  'liberal.com',
#  'kadam.com',
#  '5b5b5b.com',
#  'confianceme.com',
#  'shopatron.com',
#  'erincondren.com',
#  'kfiam640.com',
#  'thenewcode.com',
#  'totaladperformance.com',
#  'moddb.com',
#  'jiayougo.com',
#  'popsugar.com',
#  'mostlycrazy.com',
#  'codelist.com',
#  'rds.com',
#  'asterisk.com',
#  'omegatheme.com',
#  'iciporno.com',
#  'appfutura.com',
#  'incapsula.com',
#  'atlantablackstar.com',
#  'trade.com',
#  'oddup.com',
#  'ranktank.com',
#  'modirum.com',
#  'marketlinx.com',
#  'old-games.com',
#  '2001.com',
#  'ultrahdclub.com',
#  'baifubao.com',
#  'mdc.com',
#  'helppost.com',
#  'statshow.com',
#  'fundsindia.com',
#  'ecmsglobal.com',
#  'expat-dakar.com',
#  'samplicio.com',
#  '0344.com',
#  'campanianotizie.com',
#  'goldpoint.com',
#  'sbilife.com',
#  'indianstartups.com',
#  'telugusexstories.com',
#  'daiso-sangyo.com',
#  'yepan.com',
#  'optionbit.com',
#  'daftdogarcade.com',
#  'dashburst.com',
#  'napratica.com',
#  'newsitamea.com',
#  'pu.com',
#  'paradym.com',
#  'programmatileorasis.com',
#  'aeiou.com',
#  'jcyl.com',
#  'traffup.com',
#  'nwnatural.com',
#  'you.com',
#  'howfile.com',
#  'luohuedu.com',
#  'myneta.com',
#  'watermark.com',
#  'cdeledu.com',
#  'qalo.com',
#  'youreporter.com',
#  'nexpart.com',
#  'stoloto.com',
#  'verabradley.com',
#  'mysanantonio.com',
#  '4ufreeclassifiedads.com',
#  'aikf.com',
#  'schlaukopf.com',
#  'ogone.com',
#  'suzhou.com',
#  'ktv52.com',
#  'fybersearch.com',
#  'chesskid.com',
#  'duitpintar.com',
#  'tennisexplorer.com',
#  'beep.com',
#  'uncomo.com',
#  'gauleporno.com',
#  'crutchfield.com',
#  'tales-ch.com',
#  'itsthetie.com',
#  'dir.com',
#  'thosefreegames.com',
#  'optimumnutrition.com',
#  'ndtv.com',
#  'london8.com',
#  'quomodo.com',
#  '9teh-music.com',
#  'nhaccuatui.com',
#  'consul.com',
#  'sportfair.com',
#  'hightimes.com',
#  'kela.com',
#  'thehunt.com',
#  'tuyitu.com',
#  'dundee.com',
#  'fantasyalarm.com',
#  'myblogs.com',
#  '3deazer.com',
#  'nabu.com',
#  'zaful.com',
#  'sagaftra.com',
#  'nekowan.com',
#  'intellectmoney.com',
#  'relaiscolis.com',
#  'nsbank.com',
#  'chinaunix.com',
#  'a8m.com',
#  'ozgrid.com',
#  'advertise.com',
#  'zoho.com',
#  'yourdailygirls.com',
#  'webcafe.com',
#  'ss3333.com',
#  'sscaaa.com',
#  'cyclonefanatic.com',
#  'sunnyu.com',
#  'nou.com',
#  'ezship.com',
#  'fortune.com',
#  'gobiernodecanarias.com',
#  'sourcenext.com',
#  'wood168.com',
#  'acceleratelearning.com',
#  'zohopublic.com',
#  'etao.com',
#  'customs.com',
#  'dailypakistan.com',
#  'raqq.com',
#  'ca-lorraine.com',
#  'wiknix.com',
#  'zeetelugu.com',
#  'posthemes.com',
#  'wuxiaworld.com',
#  'sigmabeauty.com',
#  'watchstor.com',
#  'yunxuange.com',
#  'webcamp.com',
#  'plus-music.com',
#  'big5sportinggoods.com',
#  'master-x.com',
#  'braingle.com',
#  'p30world.com',
#  'anatomia-strasti.com',
#  'wholesaleforum.com',
#  'abc27.com',
#  'sympatiaplus.com',
#  'arabyarea.com',
#  'tuttosportweb.com',
#  'ladige.com',
#  'tattoobite.com',
#  'eldiariodeamerica.com',
#  'marlive.com',
#  'urawindow.com',
#  'thelinkindia.com',
#  'tvyaar.com',
#  'ralphlauren.com',
#  'waveapps.com',
#  'quizzclub.com',
#  'vacasa.com',
#  'gre.com',
#  'baranfilm3.com',
#  'alltipsfinder.com',
#  'lunajuegos.com',
#  'vietteltelecom.com',
#  'tcpiputils.com',
#  'seowizard.com',
#  'telefonbuch.com',
#  'factorydirect.com',
#  'fxtune.com',
#  'lnu.com',
#  'paisawapas.com',
#  'deraktionaer.com',
#  'sofree.com',
#  'aldaniti.com',
#  'lifemadeeasyglobal.com',
#  'auto-program.com',
#  'thabbet.com',
#  'kissanime.com',
#  'kronehit.com',
#  'dld.com',
#  'mrdoob.com',
#  'twishort.com',
#  'jposting.com',
#  'binpress.com',
#  'madeindesign.com',
#  'keepo.com',
#  'expatexchange.com',
#  '52cp.com',
#  'gaastraproshop.com',
#  'digital-thread.com',
#  'gigajob.com',
#  'andraste.com',
#  'dailyjobresult.com',
#  'globalshoes.com',
#  'k-pandora.com',
#  'tripwire.com',
#  'furgonetka.com',
#  'tving.com',
#  'uwcu.com',
#  'vaygmedia.com',
#  'free-tv-video-online.com',
#  'nc.com',
#  'uma.com',
#  'tqqa.com',
#  'lennar.com',
#  'simit.com',
#  'dailyfreeman.com',
#  'com--congrats.com',
#  'coxandkings.com',
#  'qoqa.com',
#  'sheamoisture.com',
#  'i-gay.com',
#  'digitallook.com',
#  'marthadebayle.com',
#  'manifo.com',
#  'skyscrapercity.com',
#  'sitesuccessful.com',
#  '0img.com',
#  'hdxnxx.com',
#  'saudigamer.com',
#  'meloman.com',
#  'cpna.com',
#  'hanenlove.com',
#  'ukclimbing.com',
#  'u-ryukyu.com',
#  'ooreka.com',
#  'bk-ligastavok.com',
#  'iqoption.com',
#  'crackhex.com',
#  'wayne.com',
#  'rorierodouga.com',
#  'vakilsearch.com',
#  'cnw.com',
#  'parsonline.com',
#  'animeseason.com',
#  'ppxsw.com',
#  '15minutenews.com',
#  'irdiplomacy.com',
#  'theplanetd.com',
#  'ad1.com',
#  'kemenag.com',
#  'kia-sa.com',
#  'redhat.com',
#  'vibethemes.com',
#  'dramayou.com',
#  'magestore.com',
#  'myarena.com',
#  'skokka.com',
#  'develop-online.com',
#  'yeditepe.com',
#  'expresdiario.com',
#  'taifex.com',
#  'udesc.com',
#  'bankbazaar.com',
#  'xatakahome.com',
#  'asrehamoon.com',
#  'kantei.com',
#  'mendozapost.com',
#  'kennedy-center.com',
#  'bunkaikoubou.com',
#  'calmclinic.com',
#  'supermomguide.com',
#  'adoptapet.com',
#  'dogdrip.com',
#  'stickam.com',
#  'step-japan.com',
#  'canonistas.com',
#  'aircraftspruce.com',
#  'djmaza.com',
#  'haohaizi.com',
#  'xjufe.com',
#  'myenglishpages.com',
#  'ttvnol.com',
#  'knowyourinside.com',
#  'blsk.com',
#  'beyazperde.com',
#  'k-solution.com',
#  'wmrok.com',
#  'vuku.com',
#  'calcal.com',
#  'olo.com',
#  'agenciamestre.com',
#  'artbeads.com',
#  'krogerkrazy.com',
#  'camer.com',
#  'hengyan.com',
#  'redlobster.com',
#  'turkishtv.com',
#  'dreamjordan.com',
#  'uady.com',
#  'ecartel.com',
#  'abw.com',
#  'tivo.com',
#  'searchgol.com',
#  'adageindia.com',
#  'skatedeluxe.com',
#  'chordtabs.com',
#  'wamba.com',
#  'galerafilmes.com',
#  'kabalarians.com',
#  'forum2x2.com',
#  'talbots.com',
#  'ciim.com',
#  'astyle.com',
#  'skijumping.com',
#  'spreeder.com',
#  'inderscience.com',
#  'travellerspoint.com',
#  'gamebiz.com',
#  'eumed.com',
#  'efpfanfic.com',
#  'news9.com',
#  'myswitzerland.com',
#  'chinaexhibition.com',
#  'v-n-zb.com',
#  'wildelifecomic.com',
#  'spaziogames.com',
#  'balkanweb.com',
#  'dogspot.com',
#  'rfrr.com',
#  'shoptips.com',
#  'arabhardware.com',
#  'planet-wissen.com',
#  'freedoge.com',
#  'sinhvienit.com',
#  'segmentfault.com',
#  'applion.com',
#  'cosplayjav.com',
#  'lolboom.com',
#  'playporngames.com',
#  'fundacity.com',
#  'remote-learner.com',
#  'tipsfound.com',
#  'couponzeta.com',
#  'ncsu.com',
#  'enstage.com',
#  'biletbank.com',
#  'sellercube.com',
#  'rtlxl.com',
#  'stephenmorley.com',
#  'mintpressnews.com',
#  'indiaeducation.com',
#  'samsungfire.com',
#  'hootsuite.com',
#  'seed.com',
#  'channelate.com',
#  'irecommend.com',
#  'rockpapershotgun.com',
#  'coupahost.com',
#  'jazzmyride.com',
#  'desiserials.com',
#  'alkosto.com',
#  'njumobile.com',
#  'waplog.com',
#  'popitunder.com',
#  'multiele.com',
#  'id8888.com',
#  'nijigenshingu.com',
#  'arabsharing.com',
#  'spartoo.com',
#  'hikvision.com',
#  'ubldirect.com',
#  'ero-lust.com',
#  'zhimg.com',
#  'lazada.com',
#  'njlottery.com',
#  'buffalostate.com',
#  'johnshopkins.com',
#  'boxofads.com',
#  'jakartanotebook.com',
#  'themegrill.com',
#  'cminds.com',
#  'atwikiimg.com',
#  'zgcy.com',
#  'douknow.com',
#  'hw-go.com',
#  'extensionfactory.com',
#  'webcashmgmt.com',
#  'minhateca.com',
#  'indianpornvideos.com',
#  'spickipedia.com',
#  'fitbodycare.com',
#  'findthebest.com',
#  'codyapp.com',
#  'bbcollab.com',
#  'tidal.com',
#  'abcnews.com',
#  'cervantesvirtual.com',
#  'grif-fan.com',
#  ...]

# %%
print(len(domains_train), len(domains_valid), len(domains_test))
# Out:
# 69723 3670 18349

# %%
import os
os.mkdir('domain_pics')
os.mkdir('domain_pics/train')
os.mkdir('domain_pics/test')
os.mkdir('domain_pics/valid')

# %%
for domain in domains_train:
    img(domain, 'domain_pics/train/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-16-fb8d07dd24a5> in <module>()
#       1 for domain in domains_train:
# ----> 2     img(domain, 'domain_pics/train/')
#
# <ipython-input-5-9e45b82a2008> in img(text, path)
#       1 def img(text, path):
#       2     img = Image.new('L', (150, 12))
# ----> 3     fnt = ImageFont.truetype(font, 10)
#       4     d = ImageDraw.Draw(img)
#       5     d.text((0, 0), text, font=fnt, fill = (255))
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     640
#     641     try:
# --> 642         return freetype(font)
#     643     except OSError:
#     644         if not isPath(font):
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in freetype(font)
#     637
#     638     def freetype(font):
# --> 639         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     640
#     641     try:
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     186                     return
#     187             self.font = core.getfont(
# --> 188                 font, size, index, encoding, layout_engine=layout_engine
#     189             )
#     190         else:
#
# OSError: cannot open resource

# %%
for domain in domains_test:
    img(domain, 'domain_pics/test/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-7bfa68ffbb13> in <module>()
#       1 for domain in domains_test:
# ----> 2     img(domain, 'domain_pics/test/')
#
# <ipython-input-5-9e45b82a2008> in img(text, path)
#       1 def img(text, path):
#       2     img = Image.new('L', (150, 12))
# ----> 3     fnt = ImageFont.truetype(font, 10)
#       4     d = ImageDraw.Draw(img)
#       5     d.text((0, 0), text, font=fnt, fill = (255))
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     640
#     641     try:
# --> 642         return freetype(font)
#     643     except OSError:
#     644         if not isPath(font):
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in freetype(font)
#     637
#     638     def freetype(font):
# --> 639         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     640
#     641     try:
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     186                     return
#     187             self.font = core.getfont(
# --> 188                 font, size, index, encoding, layout_engine=layout_engine
#     189             )
#     190         else:
#
# OSError: cannot open resource

# %%
for domain in domains_valid:
    img(domain, 'domain_pics/valid/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-2831e3cdb088> in <module>()
#       1 for domain in domains_valid:
# ----> 2     img(domain, 'domain_pics/valid/')
#
# <ipython-input-5-9e45b82a2008> in img(text, path)
#       1 def img(text, path):
#       2     img = Image.new('L', (150, 12))
# ----> 3     fnt = ImageFont.truetype(font, 10)
#       4     d = ImageDraw.Draw(img)
#       5     d.text((0, 0), text, font=fnt, fill = (255))
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     640
#     641     try:
# --> 642         return freetype(font)
#     643     except OSError:
#     644         if not isPath(font):
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in freetype(font)
#     637
#     638     def freetype(font):
# --> 639         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     640
#     641     try:
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     186                     return
#     187             self.font = core.getfont(
# --> 188                 font, size, index, encoding, layout_engine=layout_engine
#     189             )
#     190         else:
#
# OSError: cannot open resource

# %%
train = [dom[1] for dom in data['train']][:69723]
test = [dom[1] for dom in data['test']][:18349]
valid = [dom[1] for dom in data['validate']][:3670]

# %%
train
# Out:
# ['okayplaiier.com',
#  'o-keyplayer.com',
#  'okayplayez.com',
#  'okayðlayer.com',
#  'okayplàyeřȑ.com',
#  'õkaÿðlayer.com',
#  'ojayƥlayer.com',
#  'okaýðlayer.com',
#  'okeypplaŷer.com',
#  'ecobolsas.com',
#  'ecobollsah.com',
#  'ecoboll_si.com',
#  'ecøbolsa.com',
#  'ecøbolsä.com',
#  'ecoƀolŝá.com',
#  'ecobolșan.com',
#  'ecoƀōl5a.com',
#  'ečobolsla.com',
#  'listalb.com',
#  'lis4l.com',
#  'listl_f.com',
#  'listał.com',
#  'ĺıstal.com',
#  'ļisŧaļ.com',
#  'lmʂtal.com',
#  'liş7al.com',
#  'ilsʈl.com',
#  'webirectory.com',
#  'webdhrectopy.com',
#  'vebdirmctopy.com',
#  'webdirēctory.com',
#  'webƌirectõry.com',
#  'webďiręctořȑy.com',
#  'webďirec_tory.com',
#  'webtírectóry.com',
#  'webƋirectopyo.com',
#  'g-eteasysolution.com',
#  'geteasysolutkin.com',
#  'geteasyysolutokn.com',
#  'geteasysolutïon.com',
#  'geteasẏsoļution.com',
#  'gęteasysoluťioñ.com',
#  'ģeteasysolutino.com',
#  'geteasysōluʈon.com',
#  'geteašysolu4oin.com',
#  'chem4jids.com',
#  'chemk4ils.com',
#  'cheakils.com',
#  'chem4ķids.com',
#  'chem4kiďʂ.com',
#  'chêm4ķidș.com',
#  'chem4kies.com',
#  'ćhem4ķidss.com',
#  'chem4ķilsm.com',
#  '2chmatome2b.com',
#  '2chmato-e.com',
#  '2chmtoee.com',
#  '2chmațome2.com',
#  '2ćhmatöme2.com',
#  '2cħɱatome2.com',
#  '2chmatonē2.com',
#  '2chmãtomé_2.com',
#  '2chmaťomeq.com',
#  'thegraciouspantrq.com',
#  'thegrcciouspentry.com',
#  'thefrccious0antry.com',
#  'thegraciousðantry.com',
#  'thegraciousƥaŋtry.com',
#  'thęgraçiouspantrÿ.com',
#  'thegrasiouspanťry.com',
#  'thegraaciouspãntɍy.com',
#  'theģrcciouspantryl.com',
#  'vonagebusinessi.com',
#  'vonagebusineswx.com',
#  'vonagebuslneswn.com',
#  'vonagebusinesş.com',
#  'vonagebȕšiness.com',
#  'vonagebuŝińèss.com',
#  '6onagebusiness.com',
#  'vongaebusïŋess.com',
#  'vonagebusynesẅ.com',
#  'gettyu.com',
#  'gtet_y.com',
#  'gteLy.com',
#  'gettẏ.com',
#  'ğeťty.com',
#  'ģēțty.com',
#  'ggttÿ.com',
#  'ġet_tŷ.com',
#  'gtétyx.com',
#  '7ired.com',
#  'wiiredj.com',
#  '_wiirdd.com',
#  'wiřȑed.com',
#  'Ŵireď.com',
#  'wîȓèd.com',
#  'wirēdv.com',
#  'ẅiȓedd.com',
#  'wiireƌr.com',
#  'msgfocusu.com',
#  'msggfo-cus.com',
#  'msgfo-_cuc.com',
#  'msgfōcus.com',
#  'ɱsgfocüs.com',
#  'mşgſõcus.com',
#  'ɱsgfocvs.com',
#  'mẃgfocµs.com',
#  'm_sgfo-cus.com',
#  'ushgrbrooke.com',
#  'usherbrookezh.com',
#  'uqher8rookez.com',
#  'usherbrooķe.com',
#  'uŝherbrooķe.com',
#  'µšherƀrooke.com',
#  'ushęrb2ooke.com',
#  'úsheŕbrooken.com',
#  'usiherbrooķez.com',
#  'audi_usa.com',
#  'audi_usat.com',
#  'audyurat.com',
#  'auđiusa.com',
#  'auďiùsa.com',
#  'audĩµśa.com',
#  'uâdiusa.com',
#  'auţiuʂa.com',
#  'aufiȗsat.com',
#  'li0nbridge.com',
#  'lionbridldge.com',
#  'liof-briddge.com',
#  'lioņbridge.com',
#  'łionbŕidge.com',
#  'ļionƀȓidge.com',
#  'lionbrįdqe.com',
#  'lionbřȑídgee.com',
#  'lĭobriddge.com',
#  'megagamesa.com',
#  '-egagamus.com',
#  '-eyagamest.com',
#  'megàgames.com',
#  'ɱegagámes.com',
#  'měgāgamės.com',
#  'megagämest.com',
#  'legägamës.com',
#  '-egagamesŀ.com',
#  'chinair.com',
#  'hi_nahr.com',
#  'hijahre.com',
#  'chinaĥr.com',
#  'chíŉahr.com',
#  'chiņàhɍ.com',
#  'cchinąhr.com',
#  'ċhiņahrj.com',
#  '_hinaĥr.com',
#  'christmastreeshopsr.com',
#  'christmastreeeshoops.com',
#  'christmastrees4o-ops.com',
#  'christmaʂtreeshops.com',
#  'christmastřȑeeshopś.com',
#  'chrĭsʈmastreeshőps.com',
#  'chrístmastreeshopsn.com',
#  'cĥristmåstreesiops.com',
#  'cħristmastreshoops.com',
#  'koukuok.com',
#  'lkoekuko.com',
#  'lkoukukohp.com',
#  'kouķuko.com',
#  'kōukųko.com',
#  'kòűkuķo.com',
#  'kou_kuko.com',
#  'koükuķ0.com',
#  'lkoukülco.com',
#  'arrowheadpridex.com',
#  'ar_rwheadpride.com',
#  'ar_rowhheadrpide.com',
#  'arrowheadþride.com',
#  'arrowheådprīde.com',
#  'arrŏwhěãdpride.com',
#  'árrowheadpridep.com',
#  'arrowħeadpriiƌe.com',
#  'âr_powheadpride.com',
#  'senttijatt.com',
#  'sentijattd.com',
#  'senti_jattfg.com',
#  'sențijatt.com',
#  'sențijaʈt.com',
#  'ŝentiĵătt.com',
#  'sěntijatf.com',
#  '3entĩjatt.com',
#  'wenʈijattf.com',
#  'av3ws.com',
#  'avswr_.com',
#  'evsur.com',
#  'avsẁs.com',
#  'āvswś.com',
#  'âṿswʂ.com',
#  'avʂwws.com',
#  'ávswsù.com',
#  'așvwr.com',
#  'rosneft_.com',
#  'rosheftu.com',
#  'rosnefuuv.com',
#  'rosnèft.com',
#  'řȑosnefŧ.com',
#  'roŝńefť.com',
#  'rosneft_.com',
#  'rosnēfʈk.com',
#  'rosneğtu.com',
#  'app_leuser.com',
#  'aptleuser_.com',
#  'appleeser_v.com',
#  'appleuseɍ.com',
#  'àppleűser.com',
#  'appļeűsėr.com',
#  'ațpleuser.com',
#  'app_léuseŕ.com',
#  'appleusër_.com',
#  'corefftp.com',
#  'covefttp.com',
#  'corr_efttp.com',
#  'corėftp.com',
#  'coreſțp.com',
#  'cöreƒtƥ.com',
#  'cöreftt.com',
#  'cnrĕfʈp.com',
#  'coretftƥ.com',
#  'ssiriust.com',
#  'sirius7n.com',
#  '_siriustm.com',
#  'siriusť.com',
#  'sįrįust.com',
#  'širiűsţ.com',
#  'syriûst.com',
#  '3iriuşʈ.com',
#  'si-riustŋ.com',
#  'feeb.com',
#  'febak.com',
#  'febcw.com',
#  'feƀe.com',
#  'ƒēbe.com',
#  'fēƀē.com',
#  'ƒebej.com',
#  'ſelbĕ.com',
#  'fȗba.com',
#  'ucv.com',
#  'ucft.com',
#  'ucf6.com',
#  'uċ.com',
#  'ūċ.com',
#  'ūć.com',
#  'ucµ.com',
#  'uċć.com',
#  'ȗcf.com',
#  'rideohive.com',
#  'vidie_ohive.com',
#  'vhdiieohive.com',
#  'videøhive.com',
#  'videohîṿe.com',
#  'ṿiƌéohive.com',
#  'riđeohive.com',
#  'viďeøiive.com',
#  'vidièohiver.com',
#  'esoreater.com',
#  'esoer-iter.com',
#  'esora-iteb.com',
#  'esoreīter.com',
#  'esorěiteŗ.com',
#  'éŝŏreiter.com',
#  'esopeíter.com',
#  'esoreiʈėrs.com',
#  'esobe-itęr.com',
#  'xxxsexxxy.com',
#  'xxxseyxp.com',
#  'xxxsexppy.com',
#  'xxxșexxx.com',
#  'xẍxsexxẍ.com',
#  'xxxsè×ẋx.com',
#  'xxxexx×.com',
#  'xx×suxxẍ.com',
#  'x_xxsexxƥ.com',
#  'f-cf.com',
#  'cffk.com',
#  'cfbg.com',
#  'fcƒ.com',
#  'ſçf.com',
#  'ƒçſ.com',
#  'fcƒz.com',
#  'fcƒƒ.com',
#  'cfƒ_.com',
#  'y8799.com',
#  '9899t.com',
#  '1899h.com',
#  '98799.com',
#  '98799.com',
#  '98799.com',
#  'y8799.com',
#  '98799e.com',
#  '9899_.com',
#  'wetterprognowe-wettervorhersage.com',
#  'wetterprognose-wettervorhersaoem.com',
#  'wetterprogno_se-wettervorheersagem.com',
#  'wetterprognose-wēttervorhersage.com',
#  'wetterprognose-weʈtervorheȓsage.com',
#  'wetterprognose-wetteȓṿorheršage.com',
#  'wetterprogmose-wettervorhěrsage.com',
#  'wettĕrprognose-wettervorherșagef.com',
#  'wetterp2ognose-wețtervorhersagem.com',
#  'tnednet.com',
#  'thebne.com',
#  'tnebnelt.com',
#  'tñebnet.com',
#  'tnebŉēt.com',
#  'ʈněƀnet.com',
#  'tnebênt.com',
#  'țņeb_net.com',
#  'tnebněf.com',
#  'poroway.com',
#  'p-o-rnway.com',
#  'p-ornwq.com',
#  'porňway.com',
#  'poŗnwaý.com',
#  'ðoɍnwày.com',
#  'po_rnwaŷ.com',
#  'pȓnwaẏ.com',
#  'p-mȓnway.com',
#  'pconlne.com',
#  'pcoonlinep.com',
#  'pcoonliend.com',
#  'pconlinę.com',
#  'pċonlıne.com',
#  'ƥĉonlinĕ.com',
#  'pĉonlinu.com',
#  'pconliřȑĕ.com',
#  'pcoonliŋex.com',
#  'ced5.com',
#  'cmd7l.com',
#  'cmb5lb.com',
#  'cmƌ5.com',
#  'çɱd5.com',
#  'čmď5.com',
#  'ĉmd5a.com',
#  'ɱƋ5.com',
#  'cmd5li.com',
#  'seelkayem.com',
#  'seukaiem.com',
#  'seeukayen.com',
#  'seėkayem.com',
#  'seëkāyem.com',
#  'seêkăýem.com',
#  'seekãyern.com',
#  'sĕekaye-.com',
#  'seuõayem.com',
#  'mylocalserv1ces.com',
#  'mylocalser-vicesn.com',
#  'myikcalser-vices.com',
#  'mylocalservïces.com',
#  'mylocalsērṿices.com',
#  'mylocàlservíceş.com',
#  'mylocålservices.com',
#  'myloca1sērviĉes.com',
#  'mylkcalșer-vices.com',
#  'tayaba.com',
#  't-ayapa.com',
#  't-ayapac.com',
#  'ťayara.com',
#  'ʈayąra.com',
#  'taẏąŕa.com',
#  '7ayaŗa.com',
#  'tayāșa.com',
#  't-aŷ-ara.com',
#  'boattsader.com',
#  'lboattradern.com',
#  'lcoattrade.com',
#  'boattradeŕ.com',
#  'bôattradeɍ.com',
#  'bòattrađeȓ.com',
#  'ƀoatttrader.com',
#  'böattardĕr.com',
#  'lbaottradeŗ.com',
#  'searhfunmoods.com',
#  'searcxfunmnods.com',
#  's_earc8funmoods.com',
#  'seaȓchfunmoods.com',
#  'sęârchfunmoods.com',
#  'seaȓchfuñmoóds.com',
#  'searchſunmoodsw.com',
#  'searchfȗņmooods.com',
#  'searc×fumnoods.com',
#  'jjmbullion.com',
#  'jbmullion.com',
#  'jmlbullionn.com',
#  'jmbulliön.com',
#  'ĵmbullĭon.com',
#  'jmbùŀļion.com',
#  'j-ɱbullion.com',
#  'ĵɱb_ullion.com',
#  'jmbullìn.com',
#  'kulsher.com',
#  'kltshe.com',
#  'ktls_le.com',
#  'kułshe.com',
#  'kułsĥe.com',
#  'ķũlŝhe.com',
#  'ķulshem.com',
#  'kulsĥér.com',
#  'ktł3he.com',
#  'parscup.com',
#  'parw-ctp.com',
#  'pars-afp.com',
#  'paɍs-cup.com',
#  'ðařȑs-cup.com',
#  'pärś-cup.com',
#  'parśc-up.com',
#  'ðars-ĉupo.com',
#  'pars-ctpŝ.com',
#  'loopthelinksp.com',
#  'loortheelinks.com',
#  'loorth_elinks.com',
#  'looptheliñks.com',
#  'ļoopthėlinks.com',
#  'loopthëliŉkŝ.com',
#  'looƥtheilnks.com',
#  'lōopthųlinks.com',
#  'loorʈhelinos.com',
#  'mydksh.com',
#  'mdyisha.com',
#  'mdyh5h.com',
#  'mÿdish.com',
#  'myđisħ.com',
#  'myƋįsħ.com',
#  'mydisĥ_.com',
#  'nnyďısh.com',
#  'mdiisħ.com',
#  'piniu.com',
#  'siriu.com',
#  'qiriufm.com',
#  'qińiu.com',
#  'ɋiŉiu.com',
#  'qińĩù.com',
#  'ԛinium.com',
#  'ɋiniũl.com',
#  'qrîiu.com',
#  'oxicaslh.com',
#  'oxicashe.com',
#  'oxicashumr.com',
#  'oxicasħ.com',
#  'øxîcash.com',
#  'oxıçašh.com',
#  'oxicas_ĥ.com',
#  'oẋyčash.com',
#  'oxîc4shu.com',
#  'webzenn.com',
#  'wabze-n.com',
#  'uabze_n.com',
#  'webẕen.com',
#  'ẁebžen.com',
#  'wĕbžėn.com',
#  'w-ebżen.com',
#  'weƀźenn.com',
#  'wa6zěn.com',
#  'fhemm.com',
#  'fhemcn.com',
#  'theec.com',
#  'fheɱ.com',
#  'fĥeɱ.com',
#  'ƒħeɱ.com',
#  'fhe_ɱ.com',
#  'ſ4em.com',
#  'fńemc.com',
#  'mygara_ge.com',
#  'mycar-age.com',
#  'myca-2age.com',
#  'mygaŕage.com',
#  'mygarâgė.com',
#  'mýġaŕage.com',
#  'mygarağew.com',
#  'myſaɍage.com',
#  'mycaraƒe.com',
#  'cutl.com',
#  'cpu1.com',
#  'cvp1u.com',
#  'ċupl.com',
#  'ĉȗpl.com',
#  'čȕpļ.com',
#  'cuð_l.com',
#  'c_ūpl.com',
#  'cup1f.com',
#  'infosrilankanaws.com',
#  'infosrilaknaoews.com',
#  'infosirlinkaoews.com',
#  'inſosrilankanews.com',
#  'infosrilankaněẁs.com',
#  'infosrilåńkañews.com',
#  'infösrilanka-news.com',
#  'iŉfocrilanķanews.com',
#  'infowrilankaoėws.com',
#  'trbunist.com',
#  'tbibunistl.com',
#  'tribunmstlc.com',
#  'tribũnist.com',
#  'tribuŋiśt.com',
#  'ŧriƀunișt.com',
#  'tribŭfist.com',
#  'trībunisțt.com',
#  'trib_unisțl.com',
#  'xeliculasio.com',
#  'peliculasi-of.com',
#  'pelic5nasi-o.com',
#  'peliculasiŏ.com',
#  'þelicůlasio.com',
#  'pėlicuĺaśio.com',
#  'peliċulacio.com',
#  'tēlicūlasio.com',
#  'pe1iculaʂi-o.com',
#  'kora-_online.com',
#  'cora-on_line.com',
#  'kora_-on_lined.com',
#  'kora-onlïne.com',
#  'koră-onlíne.com',
#  'kora-önlınë.com',
#  'kora-o_nline.com',
#  'kosa-oŋlińe.com',
#  'koora-on_ŀine.com',
#  'wdniles.com',
#  'udfile3.com',
#  'wd-file2.com',
#  'ẉdfiles.com',
#  'ẇdƒiles.com',
#  'Ŵdfilĕś.com',
#  'wdf_iles.com',
#  'Ŵd-ſiles.com',
#  'wfdilě3.com',
#  'newhuay.com',
#  'neu-hua.com',
#  'n-ew-huam.com',
#  'newĥua.com',
#  'ńewħua.com',
#  'nēẇĥua.com',
#  'newhuaţ.com',
#  'ŉeẅhuc.com',
#  'ňwe-hua.com',
#  'htm5lxcss3.com',
#  'ntml5xcss3p.com',
#  'htmd5xcss3pz.com',
#  'html5xcšs3.com',
#  'htɱl5xćss3.com',
#  'htmľ5ẋcss3.com',
#  'html5xaʂs3.com',
#  'htmľ5xcqs3.com',
#  'htɱh5xcss3p.com',
#  '9g0.com',
#  '980g.com',
#  '98-0.com',
#  '990.com',
#  '990.com',
#  '990.com',
#  '190.com',
#  '990u.com',
#  '80.com',
#  'sho_polog.com',
#  'whopoloc.com',
#  's-hopolocr.com',
#  'shopoloģ.com',
#  'șhoþolog.com',
#  'sĥőpølog.com',
#  'shopołmg.com',
#  'shõpoľogx.com',
#  'whoƥoloc.com',
#  'djx.com',
#  'tjpl.com',
#  'tjxlyr.com',
#  'tĵx.com',
#  'tĵ×.com',
#  'ʈĵẋ.com',
#  'pjẍ.com',
#  'ʈjxĥ.com',
#  'tjẍ.com',
#  '0755caar.com',
#  '0T55cer.com',
#  '0155cer.com',
#  '0755caŕ.com',
#  '0755ċar.com',
#  '0755čáȓ.com',
#  '0755caɍo.com',
#  '0755ĉås.com',
#  '0775cer.com',
#  'ngheaty.com',
#  'hghmatyl.com',
#  'n6hma4yl.com',
#  'nghmaʈy.com',
#  'ňghmaŧy.com',
#  'ňgĥmăty.com',
#  'nĝjmaty.com',
#  'ngīmaťy.com',
#  'nghmatyļ.com',
#  'pornsharingk.com',
#  'porns-harilg.com',
#  'poms-haping.com',
#  'pornsharinĝ.com',
#  'pornshãrìng.com',
#  'pornshářȑinĝ.com',
#  'pornshräing.com',
#  'pořȑnsĥairng.com',
#  'porńs-harijg.com',
#  'shockb.com',
#  'shkk.com',
#  'shcoa.com',
#  'shoĉk.com',
#  'shőcķ.com',
#  'shőçķ.com',
#  'shobķ.com',
#  'sxöçk.com',
#  'shckĥ.com',
#  'spyonwebb.com',
#  'spyolwgb.com',
#  'syoiweb.com',
#  'spyônweb.com',
#  'șpyonweƀ.com',
#  'śpyõnẃeb.com',
#  'spyon_węb.com',
#  'spẏolweƀ.com',
#  'spyolwebĵ.com',
#  'c_argurus.com',
#  'cargurusm.com',
#  'caryurusk.com',
#  'caŕgurus.com',
#  'ćargurùs.com',
#  'carġůrùs.com',
#  'carguɍrus.com',
#  'carģ5rũs.com',
#  'cargur-us.com',
#  'garagecl0thing.com',
#  'garageclotning.com',
#  'gasageclotjlng.com',
#  'gaŕageclothing.com',
#  'garāgecloțhing.com',
#  'garaġećĺothing.com',
#  'garageclothinġy.com',
#  'garàgěclotiing.com',
#  'garągeclntjing.com',
#  'boutellz.com',
#  '_b0utell.com',
#  'cutell.com',
#  'boutěll.com',
#  'boūtęll.com',
#  'bõûteĺl.com',
#  'ƀovtell.com',
#  'boūděll.com',
#  'b0ȕtells.com',
#  'daserrte.com',
#  'daserst-ei.com',
#  'dasevste.com',
#  'daserște.com',
#  'Ƌaseršte.com',
#  'đasĕrʂte.com',
#  'diaŝerste.com',
#  'đaserșteq.com',
#  'das-erst-ĕ.com',
#  'ccollectionofbestporn.com',
#  'collectiolofbertporn.com',
#  'col-lcetiolofbestporn.com',
#  'çollectionofbestporn.com',
#  'collęċtionofbestporn.com',
#  'colĺectiŏnofbesţporn.com',
#  'collectiónof6estporn.com',
#  'colleçtiōmofbestporn.com',
#  'ollectiolofbestpořȑn.com',
#  'tokiio-marui.com',
#  '_tokyo-maruir.com',
#  '_tmkyo-mar5i.com',
#  'ʈokyo-marui.com',
#  'toķyo-marui.com',
#  'tokŷõ-maŗui.com',
#  'tokyɱ-marui.com',
#  'tôcÿo-marui.com',
#  '_tokyø-rnarui.com',
#  'iasrlus.com',
#  'iasplsua.com',
#  'iasplu_sam.com',
#  'iaspluș.com',
#  'iasðļus.com',
#  'iaʂpŀuș.com',
#  'ia5pļus.com',
#  'ĩaśplvs.com',
#  'iasðlusak.com',
#  'twistrixf.com',
#  'twist-ri8.com',
#  '4wist-rlx.com',
#  'twiştrix.com',
#  'ŧẉistrix.com',
#  'twîstŕi×.com',
#  'twiqťrix.com',
#  'tẇĩ3trix.com',
#  'twist-ɍ1x.com',
#  'cosedicas_a.com',
#  'cosedigaas.com',
#  '_cosedicaasc.com',
#  'cosediĉasa.com',
#  'čosedicaša.com',
#  'çosędicaša.com',
#  'cosedìcaa.com',
#  'ģosedicaśa.com',
#  'cosedicaasħ.com',
#  'bendb5lletin.com',
#  'bendbulletin_z.com',
#  'bendbulletlnnz.com',
#  'bendbulletiň.com',
#  'bendbulŀetiň.com',
#  'beņdbȕllëtin.com',
#  'bendbulŀeitn.com',
#  'bĕndbulletin_.com',
#  'bendbuļl_etinz.com',
#  'kosovarje-ks.com',
#  'kos-ovarka-ks.com',
#  'kos-ovarja-kcp.com',
#  'kosovarja-ķs.com',
#  'kosovarja-ķŝ.com',
#  'koŝovarĵa-ķs.com',
#  'kossovarja-ķs.com',
#  'kosovarĵamkš.com',
#  'kos-ovarja-ksh.com',
#  'familyclix.com',
#  'famylyclixq.com',
#  'faymlyglix.com',
#  'famiŀyclix.com',
#  'fàmīlyclix.com',
#  'fămiĺyĉlix.com',
#  'familićlix.com',
#  'f4mīlycliẋ.com',
#  'famy1ycľix.com',
#  'wppostc.com',
#  'w9post.com',
#  'wqpste.com',
#  'wppoʂt.com',
#  'wpƥóst.com',
#  'ẉppősț.com',
#  'wpposţm.com',
#  'wpqõsť.com',
#  'ẉ-qpost.com',
#  'wotblktz.com',
#  'wot8litzp.com',
#  'woubli4zp.com',
#  'wotbĺitz.com',
#  'wötƀlitz.com',
#  'wőtbliŧž.com',
#  'voțblitz.com',
#  'wtobliťẑ.com',
#  'woțblitzpo.com',
#  'primag.com',
#  'ppimaz.com',
#  'ppin_a.com',
#  'prìma.com',
#  'pŗıma.com',
#  'þrĩmă.com',
#  'prlmã.com',
#  'přȑiɱac.com',
#  'ðpime.com',
#  'biie24.com',
#  'ike24v.com',
#  'aka24.com',
#  'ƀike24.com',
#  'ƀike24.com',
#  'ƀiķe24.com',
#  'bike2ť.com',
#  'ƀike24t.com',
#  'mķe24.com',
#  'truebilp.com',
#  'truebillk.com',
#  'turefilk.com',
#  'truebiļ.com',
#  'tȓůebil.com',
#  'tɍüebiľ.com',
#  'truebīla.com',
#  'truĕbilā.com',
#  'truebilkê.com',
#  'vidmowood.com',
#  'videmwoodi.com',
#  'vldeowoodk.com',
#  'viděowood.com',
#  'vidėowoôd.com',
#  'vîdeowöòd.com',
#  'viđeow-ood.com',
#  'vîdmowoōd.com',
#  'videòwoodl.com',
#  'sciv.com',
#  'qclw.com',
#  'clwe.com',
#  'sclṽ.com',
#  'sçļv.com',
#  'sćłṿ.com',
#  'sclṿp.com',
#  'řȑçlv.com',
#  'rcłw.com',
#  'm4elpdesk.com',
#  'mhelpdeskxk.com',
#  'mhelpdeskxyt.com',
#  'mhelpdėsk.com',
#  'mhëlpđesk.com',
#  'mhełpďęsk.com',
#  'mhelpƋeesk.com',
#  'ɱħdlpdesk.com',
#  'mhelpdesķxa.com',
#  'phdporttal.com',
#  '_phdpoortal.com',
#  'phdpo0rtalf.com',
#  'phdporťal.com',
#  'pħƌportal.com',
#  'phdpőɍtaĺ.com',
#  'phdpoɍ4al.com',
#  'phdpôþtal.com',
#  'phdpo_oȓtal.com',
#  'eazonh.com',
#  'ee-azon.com',
#  'e-azonip.com',
#  'eāzon.com',
#  'ěazön.com',
#  'ëãzoŋ.com',
#  'eẑaon.com',
#  'ězaoņ.com',
#  'e-azoňv.com',
#  'gyo.com',
#  'uuyo.com',
#  'uol.com',
#  'wÿo.com',
#  'ẃÿo.com',
#  'ẉẏó.com',
#  'ẃio.com',
#  'wŷɱ.com',
#  'űyos.com',
#  'phantomdand.com',
#  'phantomman_d.com',
#  '_pha-ntommand.com',
#  'pħantomland.com',
#  'ƥĥantomland.com',
#  'phaňtomŀänd.com',
#  'phaotoɱland.com',
#  'ðħantomlaand.com',
#  'phiňtommand.com',
#  'wantgog.com',
#  'wan-goo.com',
#  'wa_ngo_o.com',
#  'waņtgoo.com',
#  'ẃantğoo.com',
#  'ẉaňťgoo.com',
#  'want-goø.com',
#  'wântgoóu.com',
#  'wanģoob.com',
#  'x-pxzlt.com',
#  'xpxzltgd.com',
#  'xpzzltgy.com',
#  '×pxzlt.com',
#  '×pxzļt.com',
#  'xð×zlť.com',
#  'xpx_ẑlt.com',
#  'yp×źlt.com',
#  'xpẋlztg.com',
#  'cplc.com',
#  'gpkt.com',
#  'g-_pk.com',
#  'ċpk.com',
#  'ĉpķ.com',
#  'ċƥķ.com',
#  'çplk.com',
#  'ċpķd.com',
#  'gƥku.com',
#  'opazar.com',
#  'lcopazarh.com',
#  'k-opqzarh.com',
#  'kopazařȑ.com',
#  'kopaẕaŗ.com',
#  'ķõpazär.com',
#  'kopäzir.com',
#  'ooðazär.com',
#  'kopâzarhl.com',
#  'satesaude.com',
#  's-astesa_ude.com',
#  's-astesaudeot.com',
#  'sastesaůde.com',
#  'sasťesauƌe.com',
#  'ʂaŝtesäude.com',
#  'sąstesaudef.com',
#  'sasťesăude_.com',
#  's-astesauďee.com',
#  'sooftaculous.com',
#  'softaaaulous.com',
#  'sofftaaculows.com',
#  'softaçulous.com',
#  'śoftâculous.com',
#  'sôƒtaculoüs.com',
#  'soƒtaculgus.com',
#  'soƒtaculoušr.com',
#  'softaācuulous.com',
#  'followlikey.com',
#  'followlhkek.com',
#  '_follwolikek.com',
#  'fóllowlike.com',
#  'fòllowliķe.com',
#  'ſollôwliķe.com',
#  'folľowlice.com',
#  'ſllowlikĕ.com',
#  'ſollowlikekj.com',
#  'objectiffeco.com',
#  'bjctifeco.com',
#  'bjectigego.com',
#  'ōbjectifeco.com',
#  'objeĉtifećo.com',
#  'objectiƒęĉo.com',
#  'obbeçtifeco.com',
#  'oƀjeçtife_co.com',
#  'bjectifcëo.com',
#  'vivaseal.com',
#  'vitarael.com',
#  'vitareils.com',
#  'vivareål.com',
#  'vivaŗeaľ.com',
#  'vivářȑëal.com',
#  'vivaɍe_al.com',
#  'vivarãél.com',
#  'viʈaraal.com',
#  'masculindtips.com',
#  'mascuinet-ips.com',
#  'mascuineti_psj.com',
#  'masculinetıps.com',
#  'mascŭlineťips.com',
#  'masculinĕtíþs.com',
#  'mascuŀinethps.com',
#  'maʂculińetipsm.com',
#  'msacuineťips.com',
#  'cardgamespdersolitaire.com',
#  'cardgamespifer3olitaire.com',
#  'cardgames-pider3olitalre.com',
#  'carƋgamespidersolitaire.com',
#  'cardgamesþidersoĺitaire.com',
#  'cardgamespiƋersolïŧaire.com',
#  'cardgamespidėrsolitayre.com',
#  'crdgamespiďersôlitaire.com',
#  'cardgamespider3olitaireɱ.com',
#  'ceo4bookmarks.com',
#  'seo4book44arjs.com',
#  'seo_4book40arks.com',
#  'seo4boökmarks.com',
#  'seo4bookmaŗķs.com',
#  'seő4booķmarks.com',
#  'seo4booķmarksl.com',
#  'seő4boomàrks.com',
#  'seo4obok44arks.com',
#  'inofrmazione-aziende.com',
#  'informazione-qziente.com',
#  'informazigneq-ziende.com',
#  'informazìone-aziende.com',
#  'informaziône-aziendë.com',
#  'infoȓɱaźione-aziende.com',
#  'informazione-az-ieňde.com',
#  'informazione-aziendēk.com',
#  'informezione-qzieñde.com',
#  '_tibo.com',
#  'ti-bou.com',
#  'ti-6.com',
#  'tibø.com',
#  'ţîbo.com',
#  'ʈîƀo.com',
#  'tib_o.com',
#  'vįƀo.com',
#  'tí-6o.com',
#  'i_nopressa.com',
#  'inpre-ssa.com',
#  'inopre-ssaaj.com',
#  'inopresså.com',
#  'ińopresśa.com',
#  'ınoþreʂsa.com',
#  'inopreśca.com',
#  'ıngpȓessa.com',
#  'inopŗa-ssa.com',
#  'colispri-ve.com',
#  'colisprhvg.com',
#  'colsi_prhve.com',
#  'colisprîve.com',
#  'coŀisprivé.com',
#  'colísþrivė.com',
#  'colĭsprive_.com',
#  'colí3priṿe.com',
#  'coliʂp-rhve.com',
#  '9usu.com',
#  '9tssuq.com',
#  '9tsseb.com',
#  '9tsu.com',
#  '9tsȗ.com',
#  '9ʈšu.com',
#  '1ťsu.com',
#  'tʂȗ.com',
#  '9ţssuz.com',
#  'stroyortal.com',
#  'stroiipovtal.com',
#  'troii_portal.com',
#  'stroyportaĺ.com',
#  'stroŷþortal.com',
#  'stroypòrŧąl.com',
#  'sdröyportal.com',
#  'ştboyporʈal.com',
#  'qtroiipoŕtal.com',
#  'avtoomarket.com',
#  ...]

# %%
with open("fake_train.txt", "wb") as fp:
    pickle.dump(train, fp)
    
with open("fake_test.txt", "wb") as fp:
    pickle.dump(test, fp)
    
with open("fake_valid.txt", "wb") as fp:
    pickle.dump(valid, fp)

# %%
with open("fake_train.txt", "rb") as fp:
    fake_train = pickle.load(fp)
    
with open("fake_test.txt", "rb") as fp:
    fake_test = pickle.load(fp)
    
with open("fake_valid.txt", "rb") as fp:
    fake_valid = pickle.load(fp)

# %%
os.mkdir('fake_pics')
os.mkdir('fake_pics/train')
os.mkdir('fake_pics/test')
os.mkdir('fake_pics/valid')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-29-a796d5791c0f> in <module>()
# ----> 1 os.mkdir('fake_pics')
#       2 os.mkdir('fake_pics/train')
#       3 os.mkdir('fake_pics/test')
#       4 os.mkdir('fake_pics/valid')
#
# FileExistsError: [Errno 17] File exists: 'fake_pics'

# %%
for fake in fake_train:
    img(fake,'fake_pics/train/')

# %%
for fake in fake_test:
    img(fake,'fake_pics/test/')

# %%
for fake in fake_valid:
    img(fake,'fake_pics/valid/')

# %%
os.mkdir('final_train')
os.mkdir('final_train/real')
os.mkdir('final_train/phish')

os.mkdir('final_valid')
os.mkdir('final_valid/real')
os.mkdir('final_valid/phish')

os.mkdir('final_test')
os.mkdir('final_test/real')
os.mkdir('final_test/phish')

# %%
import os
from os import path
import shutil

src = "domain_pics/train/"
dst = "final_train/real/"

cnt = 0
#files = [i for i in os.listdir(src) if i.startswith("CTASK") and path.isfile(path.join(src, i))]
files = [i for i in os.listdir(src)]
for f in files:
        shutil.copy(path.join(src, f), dst)

# %%
import os
from os import path
import shutil

src = "domain_pics/test/"
dst = "final_train/real/"

cnt = 0
#files = [i for i in os.listdir(src) if i.startswith("CTASK") and path.isfile(path.join(src, i))]
files = [i for i in os.listdir(src)]
for f in files:
        shutil.copy(path.join(src, f), dst)

# %%
import os
from os import path
import shutil

src = "fake_pics/train/"
dst = "final_train/phish/"

cnt = 0
#files = [i for i in os.listdir(src) if i.startswith("CTASK") and path.isfile(path.join(src, i))]
files = [i for i in os.listdir(src)]
for f in files:
        shutil.copy(path.join(src, f), dst)

# %%
import os
from os import path
import shutil

src = "fake_pics/test/"
dst = "final_train/phish/"

cnt = 0
#files = [i for i in os.listdir(src) if i.startswith("CTASK") and path.isfile(path.join(src, i))]
files = [i for i in os.listdir(src)]
for f in files:
        shutil.copy(path.join(src, f), dst)

# %%
import os
from os import path
import shutil

src = "domain_pics/valid/"
dst = "final_valid/real/"

cnt = 0
#files = [i for i in os.listdir(src) if i.startswith("CTASK") and path.isfile(path.join(src, i))]
files = [i for i in os.listdir(src)]
for f in files:
        shutil.copy(path.join(src, f), dst)

# %%
import os
from os import path
import shutil

src = "fake_pics/valid/"
dst = "final_valid/phish/"

cnt = 0
#files = [i for i in os.listdir(src) if i.startswith("CTASK") and path.isfile(path.join(src, i))]
files = [i for i in os.listdir(src)]
for f in files:
        shutil.copy(path.join(src, f), dst)

# %% [markdown]
# Convnet

# %%
import tensorflow as tf

# %%
from keras import layers, models, optimizers

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
model.add(layers.MaxPool2D(2, 2))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPool2D(2, 2))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPool2D(2, 2))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPool2D(2, 2))
model.add(layers.Flatten())
model.add(layers.Dropout(0.5)) # Note the only change is that we added dropout here
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=1e-4),
              metrics=['acc', tf.keras.metrics.AUC()])

# %%
from keras.preprocessing.image import ImageDataGenerator

# Rescale pixel values from [0, 255] to [0, 1]
train_datagen = ImageDataGenerator(rescale=1./255) 
test_datagen = ImageDataGenerator(rescale=1./255)

# The list of classes will be automatically inferred from the subdirectory names/structure under train_dir
train_generator = train_datagen.flow_from_directory(
    'final_train',
    target_size=(256, 256), # resize all images to 224 x 224
    batch_size=50,
    class_mode='binary') # because we use binary_crossentropy loss we need binary labels

validation_generator = test_datagen.flow_from_directory(
    'final_valid',
    target_size=(256, 256),
    batch_size=50,
    class_mode='binary')
# Out:
# Found 175777 images belonging to 2 classes.
# Found 7332 images belonging to 2 classes.

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=500, 
    epochs=30,
    validation_data=validation_generator,
    validation_steps=90)
# Out:
# WARNING:tensorflow:From <ipython-input-43-3359638beb89>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/30
#   2/500 [..............................] - ETA: 47s - loss: 0.6947 - acc: 0.5200 - auc: 0.5178WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0726s vs `on_train_batch_end` time: 0.1150s). Check your callbacks.
# 500/500 [==============================] - 102s 204ms/step - loss: 0.5073 - acc: 0.7316 - auc: 0.7977 - val_loss: 0.4469 - val_acc: 0.7818 - val_auc: 0.8490
# Epoch 2/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.4440 - acc: 0.7777 - auc: 0.8399 - val_loss: 0.4201 - val_acc: 0.7944 - val_auc: 0.8667
# Epoch 3/30
# 500/500 [==============================] - 103s 205ms/step - loss: 0.4232 - acc: 0.7945 - auc: 0.8550 - val_loss: 0.3966 - val_acc: 0.8156 - val_auc: 0.8737
# Epoch 4/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.4060 - acc: 0.8117 - auc: 0.8653 - val_loss: 0.3841 - val_acc: 0.8240 - val_auc: 0.8824
# Epoch 5/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3868 - acc: 0.8233 - auc: 0.8769 - val_loss: 0.3708 - val_acc: 0.8356 - val_auc: 0.8831
# Epoch 6/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3819 - acc: 0.8242 - auc: 0.8777 - val_loss: 0.3513 - val_acc: 0.8429 - val_auc: 0.8976
# Epoch 7/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3733 - acc: 0.8302 - auc: 0.8808 - val_loss: 0.3624 - val_acc: 0.8382 - val_auc: 0.8933
# Epoch 8/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3649 - acc: 0.8338 - auc: 0.8876 - val_loss: 0.3487 - val_acc: 0.8462 - val_auc: 0.8967
# Epoch 9/30
# 500/500 [==============================] - 102s 203ms/step - loss: 0.3626 - acc: 0.8360 - auc: 0.8865 - val_loss: 0.3591 - val_acc: 0.8349 - val_auc: 0.8940
# Epoch 10/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3552 - acc: 0.8409 - auc: 0.8908 - val_loss: 0.3473 - val_acc: 0.8453 - val_auc: 0.8995
# Epoch 11/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3575 - acc: 0.8400 - auc: 0.8906 - val_loss: 0.3481 - val_acc: 0.8449 - val_auc: 0.9000
# Epoch 12/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3503 - acc: 0.8417 - auc: 0.8957 - val_loss: 0.3475 - val_acc: 0.8427 - val_auc: 0.8972
# Epoch 13/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3524 - acc: 0.8420 - auc: 0.8922 - val_loss: 0.3380 - val_acc: 0.8527 - val_auc: 0.9085
# Epoch 14/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3481 - acc: 0.8441 - auc: 0.8956 - val_loss: 0.3354 - val_acc: 0.8551 - val_auc: 0.9030
# Epoch 15/30
# 500/500 [==============================] - 102s 205ms/step - loss: 0.3409 - acc: 0.8467 - auc: 0.9020 - val_loss: 0.3460 - val_acc: 0.8444 - val_auc: 0.9009
# Epoch 16/30
# 500/500 [==============================] - 102s 205ms/step - loss: 0.3409 - acc: 0.8480 - auc: 0.9025 - val_loss: 0.3351 - val_acc: 0.8480 - val_auc: 0.9070
# Epoch 17/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3399 - acc: 0.8487 - auc: 0.9018 - val_loss: 0.3316 - val_acc: 0.8527 - val_auc: 0.9113
# Epoch 18/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3342 - acc: 0.8540 - auc: 0.9042 - val_loss: 0.3255 - val_acc: 0.8553 - val_auc: 0.9123
# Epoch 19/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3373 - acc: 0.8492 - auc: 0.9043 - val_loss: 0.3303 - val_acc: 0.8511 - val_auc: 0.9112
# Epoch 20/30
# 500/500 [==============================] - 102s 205ms/step - loss: 0.3305 - acc: 0.8545 - auc: 0.9076 - val_loss: 0.3324 - val_acc: 0.8509 - val_auc: 0.9097
# Epoch 21/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3318 - acc: 0.8531 - auc: 0.9084 - val_loss: 0.3248 - val_acc: 0.8578 - val_auc: 0.9154
# Epoch 22/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3327 - acc: 0.8521 - auc: 0.9064 - val_loss: 0.3228 - val_acc: 0.8558 - val_auc: 0.9133
# Epoch 23/30
# 500/500 [==============================] - 101s 203ms/step - loss: 0.3314 - acc: 0.8513 - auc: 0.9089 - val_loss: 0.3294 - val_acc: 0.8551 - val_auc: 0.9144
# Epoch 24/30
# 500/500 [==============================] - 103s 206ms/step - loss: 0.3237 - acc: 0.8584 - auc: 0.9114 - val_loss: 0.3239 - val_acc: 0.8569 - val_auc: 0.9122
# Epoch 25/30
# 500/500 [==============================] - 102s 205ms/step - loss: 0.3259 - acc: 0.8582 - auc: 0.9116 - val_loss: 0.3217 - val_acc: 0.8542 - val_auc: 0.9164
# Epoch 26/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3215 - acc: 0.8574 - auc: 0.9146 - val_loss: 0.3276 - val_acc: 0.8582 - val_auc: 0.9121
# Epoch 27/30
# 500/500 [==============================] - 102s 205ms/step - loss: 0.3229 - acc: 0.8566 - auc: 0.9151 - val_loss: 0.3190 - val_acc: 0.8613 - val_auc: 0.9149
# Epoch 28/30
# 500/500 [==============================] - 102s 205ms/step - loss: 0.3220 - acc: 0.8584 - auc: 0.9145 - val_loss: 0.3162 - val_acc: 0.8636 - val_auc: 0.9175
# Epoch 29/30
# 500/500 [==============================] - 102s 204ms/step - loss: 0.3186 - acc: 0.8580 - auc: 0.9172 - val_loss: 0.3212 - val_acc: 0.8576 - val_auc: 0.9125
# Epoch 30/30
# 500/500 [==============================] - 103s 205ms/step - loss: 0.3193 - acc: 0.8597 - auc: 0.9155 - val_loss: 0.3093 - val_acc: 0.8689 - val_auc: 0.9197

# %%
import matplotlib.pyplot as plt

def plot_accuracy_and_loss(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.show()

    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    plt.show()

# %%
plot_accuracy_and_loss(history)
